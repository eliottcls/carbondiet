# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# #### Load menu

# %%
import os

def relativeFilePaths(directory):
    list_paths = []
    for root, dirs, files in os.walk(os.path.relpath(directory)):
        for file in files:
            list_paths.append(os.path.join(root, file))
    return list_paths

# %%
menus = relativeFilePaths('../data/Menus')

# %%
menus
# Out:
# ['..\\data\\Menus\\burgart_205074_c70.jpg',
#  '..\\data\\Menus\\Carte-boissons-les-Ambassades-de-Montmartre-Paris-18-Restaurant-bar-terrasse.jpg.crdownload',
#  '..\\data\\Menus\\carte-du-restaurant.jpg',
#  '..\\data\\Menus\\Carte-in-seoul.png',
#  '..\\data\\Menus\\Carte-Restaurant-Nelsons-Paris-Jour-2-1024x724.jpg',
#  '..\\data\\Menus\\Carte-Restaurant-Nelsons-Paris-Jour-3-1014x1024.jpg',
#  '..\\data\\Menus\\fabbrezza_202084_665.jpg',
#  '..\\data\\Menus\\feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg',
#  '..\\data\\Menus\\in-bocca-al-lupo_42356_293.jpg',
#  '..\\data\\Menus\\menu-In-Bocca-Al-Lupo.jpg',
#  '..\\data\\Menus\\menu-PNY-BURGER-GAITE.jpg',
#  '..\\data\\Menus\\menu_bobby.jpg',
#  '..\\data\\Menus\\pasta.jpg',
#  '..\\data\\Menus\\roberta_131760_635.jpg']

# %% [markdown]
# # Computer vision task - detect meals and extract description

# %% [markdown]
# ### V1 - OpenCV & Pytesseract

# %%
import cv2

# %%
image = cv2.imread('../data/Menus/menu-PNY-BURGER-GAITE.jpg')

# %%
# transform image
#resized_image = cv2.resize(image, (800,1200))
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#blur = cv2.GaussianBlur(gray, (7,7), 0)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Create rectangular structuring element and dilate
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
dilate = cv2.dilate(thresh, kernel, iterations=4)

# %%
cv2.imshow('dilated image', dilate)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Spot the meals

# %%
# Find contours and draw rectangle
contoured_image = image.copy()
cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    cv2.rectangle(contoured_image, (x, y), (x + w, y + h), (36,255,12), 2)

# %%
cv2.imshow('contoured image', contoured_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Extract text from image portions

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'

# %%
# number of image portion
nb = 8

x,y,w,h = cv2.boundingRect(cnts[nb])
ROI = image[y:y+h,x:x+w]

text = pytesseract.image_to_string(ROI, lang='eng+fra+ita', config='--psm 6')

# %%
menu_list = []
for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    ROI = image[y:y+h,x:x+w]

    text = pytesseract.image_to_string(ROI, lang='eng+fra+ita', config='--psm 6')
    menu_list.append( re.sub('[\n|\x0c]', '', text).lower())

# %% [markdown]
# ### V2 - PaddleOCR

# %%
from paddleocr import PaddleOCR, draw_ocr

# %%
ocr = PaddleOCR(use_angle_cls=True, lang='en') # need to run only once to download and load model into memory

# [[[519.0, 1643.0], [616.0, 1643.0], [616.0, 1661.0], [519.0, 1661.0]], (' Vegetarien', 0.9622153639793396)]
# [[[638.0, 1637.0], [713.0, 1641.0], [711.0, 1665.0], [636.0, 1660.0]], ('v Vegan', 0.8755943179130554)]

# %%
from PIL import Image
image = Image.open(menus[7]).convert('RGB')
boxes = [line[0] for line in result]
txts = [line[1][0] for line in result]
scores = [line[1][1] for line in result]
im_show = draw_ocr(image, boxes, txts, scores, font_path='../ressources/fonts/simfang.ttf')
im_show = Image.fromarray(im_show)
im_show.show()

# %% [markdown]
# # NLP Task - compute carbon footprint

# %%
# Get Ademe agribalyse data
data_ademe = pd.read_excel("../data/Agribalyse/data_food.xlsx")

# Keep only first ingredients in product description name
ingredients = list(dict.fromkeys([x.split(",")[0].lower() for x in data_ademe["LCI Name"]]))

# %% [markdown]
# ##### Version 1 - Transformer chaque plat en embedding et aller cherche son plus proche voisin dans la base Ademe

# %% [markdown]
# ##### Version 2 - Localiser chaque ingrédient dans un plat et aller chercher dans la base Ademe son empreinte

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
def ingredient_check(string, list_ingredients, tresh):
    res = []
    for ingredient in list_ingredients:
        if fuzz.token_sort_ratio(string, ingredient) > tresh:
            res.append(ingredient)
        else:
            pass
    return res

def most_similar_ingredient(string, list_ingredients):
    res = "no match"
    value = 60
    for ingredient in list_ingredients:
        if fuzz.token_sort_ratio(string, ingredient) > value:
            res = ingredient
            value = fuzz.token_sort_ratio(string, ingredient)
        else:
            pass
    return res

# %%
meal = re.sub('[\n|\x0c]', '', result[0][-1][0]).split(",")
meal
# Out:
# ['LUNCH & DINNER']

# %%
menu_list = []
for r in result:
    meal = re.sub('[\n|\x0c]', '', r[-1][0]).split(",")
    meal_list = []
    for m in meal:
        meal_list.append(most_similar_ingredient(m, ingredients))
    menu_list.append(meal_list)
menu_list
# Out:
# [['no match'],
#  ['water'],
#  ['tomato sauce', 'no match'],
#  ['stuffed cabbage'],
#  ['no match'],
#  ['tomato', 'watermelon', 'no match'],
#  ['french bean', 'apples', 'no match', 'no match'],
#  ['salmon carpaccio'],
#  ['no match'],
#  ['hazelnut', 'pastry cream puff'],
#  ['salmon carpaccio', 'miso', 'no match', 'no match'],
#  ['no match'],
#  ['sweet and sour sauce'],
#  ['no match'],
#  ['no match', 'roman rocket', 'mint', 'no match'],
#  ['strawberry', 'gouda cheese', 'roman rocket', 'cucumber', 'no match'],
#  ['feta cheese', 'almond'],
#  ['shallot', 'sunflower seed'],
#  ['mint'],
#  ['no match', 'onion tart', 'no match', 'green pepper sauce'],
#  ['no match', 'artichoke base'],
#  ['no match'],
#  ['chestnut flour', 'no match', 'mustard sauce prepacked', 'almond'],
#  ['no match'],
#  ['chocolate sauce',
#   'no match',
#   'coriander',
#   'no match',
#   'sauce',
#   'red endive'],
#  ['no match'],
#  ['no match'],
#  ['no match', 'cheddar cheese', 'no match', 'fritter', 'salami'],
#  ['no match'],
#  ['no match', 'haricot bean', 'avocado', 'fritter', 'fruit salad'],
#  ['no match'],
#  ['bacon'],
#  ['no match', 'bechamel sauce', 'emmental cheese', 'fritter', 'salami'],
#  ['no match'],
#  ['no match'],
#  ['no match'],
#  ['fritter'],
#  ['no match'],
#  ['no match'],
#  ['no match'],
#  ['fresh egg pasta'],
#  ['apricots tart'],
#  ['no match'],
#  ['parmesan cheese', 'rosemary', 'no match'],
#  ['salad dressing', 'no match', 'shallot'],
#  ['no match'],
#  ['no match'],
#  ['no match', 'pomegranate', 'coriander', 'sesame oil'],
#  ['radish', 'cucumber', 'salad dressing'],
#  ['no match'],
#  ['no match'],
#  ['no match'],
#  ['no match', 'no match'],
#  ['no match', 'no match'],
#  ['nectarine'],
#  ['no match']]

# %%
pd.set_option('display.max_colwidth', None)

df_results = pd.DataFrame({"text from OCR":[x[-1][0] for x in result], "extracted components":menu_list})
df_results
# Out:
#                                                                                                    text from OCR  \
# 0                                                                                                 LUNCH & DINNER
# 1                                                                                                       STARTERS
# 2                                                                           GASPACHO TOMATE, PASTEQUE & CRABE.13
# 3                                                                                                 TARTARE TRUFFE
# 4                                                                                                          14/25
# 5                                                                    Tomato, watermelon, coriander and chive oil
# 6                                                                   French beef fillet, capers, shimeji pickles,
# 7                                                                                          CARPACCIO THON SESAME
# 8                                                                                                             15
# 9                                                                                        hazelnut, truffle cream
# 10                                        Tuna carpaccio,miso,mango and lime salsa,chilli  PASTEQUE ON THE GRILL
# 11                                                                                                           .10
# 12                                                                                            SWEET SUMMER SALAD
# 13                                                                                                        .11/20
# 14                                                                       24h marinated watermelon, rocket, mint,
# 15                                                                    Strawberry, goat cheese, rocket, cucumber,
# 16                                                                                           feta cheese, almond
# 17                                                                                      shallot, sunflower seeds
# 18                                                                                                         MAINS
# 19             PARIS LONDON RUMSTEAK (240G) French beef, onion rings, cafe de Paris butter, pepper sauce .... 34
# 20                                                  MISO SALMON Raw and cooked white asparagus, artichoke mousse
# 21                                                                                                            26
# 22                          CHOU-FLEUR, BOULGOUR & FIGUES Roasted cauliflower, parsley mustard sauce, almond....
# 23                                                                                                            19
# 24                       MOULES & CHIPS xO sauce, shoestring chips, coriander, citrus spices, sucrine, endive...
# 25                                                                                                            23
# 26                                                                                                HOX SIGNATURES
# 27                                     HOX CHEESEBURGER Spanish beef, cheddar, caramelized onions, fries, salad.
# 28                                                                                                            20
# 29                     BEYOND MEAT VEGGIE BURGER Beyond Meat pattiee, charcoal bun, avocado, fries, salad.... 18
# 30                                                                    Add truffle fries or sweet potato fries +2
# 31                                                                                                   Add bacon+3
# 32                          HOX MONSIEUR TRUFFE Parisian ham, truffle bechamel, Emmental cheese, fries, salad...
# 33                                                                                                           .22
# 34                                                                                              Add fried egg +2
# 35                                                                                                         SIDES
# 36                                                                                                   FRITES (v).
# 37                                                                                             FRITES TRUFFE (v)
# 38                                                                                                             4
# 39                                                                                                             6
# 40                                                                                           FRITES PATATE DOUCE
# 41                                                                                      8  HARICOTS VERTS TRUFFE
# 42                                                                                                             8
# 43                                                                          Parmesan cheese,rosemary, spicy mayo
# 44                                                                         Truffle dressing, crispy egg, shallot
# 45                                                                                         NAUGHTY AUBERGINE (v)
# 46                                                                                       SPICY SALADE MIZUNA (v)
# 47                                                                   Miso glazed, pomegranate, coriander, sesame
# 48                                                                             Radish, cucumber, korean dressing
# 49                                                                                                   @RIVIEPARIS
# 50  If you have any food allergies or intolerances please let us know.The allergens list is available on request
# 51                                                                  Prices are net in including 10% VAT on food.
# 52                          We do not accept restaurant tickets on weekend and evening, and can not be returned.
# 53                                                                    We don't accept checks,200e and 500 notes.
# 54                                                                                                    Vegetarien
# 55                                                                                                       v Vegan
#
#                                                    extracted components
# 0                                                            [no match]
# 1                                                               [water]
# 2                                              [tomato sauce, no match]
# 3                                                     [stuffed cabbage]
# 4                                                            [no match]
# 5                                        [tomato, watermelon, no match]
# 6                             [french bean, apples, no match, no match]
# 7                                                    [salmon carpaccio]
# 8                                                            [no match]
# 9                                         [hazelnut, pastry cream puff]
# 10                         [salmon carpaccio, miso, no match, no match]
# 11                                                           [no match]
# 12                                               [sweet and sour sauce]
# 13                                                           [no match]
# 14                             [no match, roman rocket, mint, no match]
# 15         [strawberry, gouda cheese, roman rocket, cucumber, no match]
# 16                                                [feta cheese, almond]
# 17                                            [shallot, sunflower seed]
# 18                                                               [mint]
# 19                 [no match, onion tart, no match, green pepper sauce]
# 20                                           [no match, artichoke base]
# 21                                                           [no match]
# 22          [chestnut flour, no match, mustard sauce prepacked, almond]
# 23                                                           [no match]
# 24  [chocolate sauce, no match, coriander, no match, sauce, red endive]
# 25                                                           [no match]
# 26                                                           [no match]
# 27                [no match, cheddar cheese, no match, fritter, salami]
# 28                                                           [no match]
# 29              [no match, haricot bean, avocado, fritter, fruit salad]
# 30                                                           [no match]
# 31                                                              [bacon]
# 32         [no match, bechamel sauce, emmental cheese, fritter, salami]
# 33                                                           [no match]
# 34                                                           [no match]
# 35                                                           [no match]
# 36                                                            [fritter]
# 37                                                           [no match]
# 38                                                           [no match]
# 39                                                           [no match]
# 40                                                    [fresh egg pasta]
# 41                                                      [apricots tart]
# 42                                                           [no match]
# 43                                [parmesan cheese, rosemary, no match]
# 44                                  [salad dressing, no match, shallot]
# 45                                                           [no match]
# 46                                                           [no match]
# 47                       [no match, pomegranate, coriander, sesame oil]
# 48                                   [radish, cucumber, salad dressing]
# 49                                                           [no match]
# 50                                                           [no match]
# 51                                                           [no match]
# 52                                                 [no match, no match]
# 53                                                 [no match, no match]
# 54                                                          [nectarine]
# 55                                                           [no match]
