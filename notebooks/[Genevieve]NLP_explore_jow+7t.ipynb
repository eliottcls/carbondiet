# %% [markdown]
# # NLP exploration - 4 (executed on Google Colab)
# Here we repeat the most promising tests done in previous notebooks (NLP_explore.ipynb, NLP_explore_en.ipynb, NLP_explore_build_recipe.ipynb) for the big recipe database obtained by concatening JOW + 7tomorrow.

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import re
import time
import seaborn as sns
import itertools

# %% [markdown]
# ## Google colab settings
# Show the gpu infos and change if needed in "Execution" panel.
# Using GPUs is not compulsory here. I moved to Google Colab because my computer is slow.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Feb 27 15:09:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Import from Google Drive.
# Here the folder 'carbondiet4GD' only contains the folder data/ with subfolders Recipes/ and Tools/ (others are not used).

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/carbondiet4GD.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')     # create a copy directly in colab for efficiency reasons
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Indicate the path where the folder data/ is located.**

# %%
#data_path = '../'
data_path = 'carbondiet4GD/'

# %% [markdown]
# ## Import and prepare the menu database
# Import the file that has been prepared with a list of menu recipes and their corresponding 7t and/or JOW recipes.
# Note that the matching has been done by hand in a former step (and may contain errors).

# %%
menu_data = pd.read_json(data_path+'data/Tools/MenuTo7tJOWRecipes_v1.json')
menu_data.head(10)
# Out:
#              Menu filename  Menu Title                          Menu Subtitle  \
# 0   burgart_205074_c70.jpg     Burgers                               Superfin
# 1   burgart_205074_c70.jpg     Burgers                             Bon & Beau
# 3   burgart_205074_c70.jpg     Burgers                          Green Chicken
# 4   burgart_205074_c70.jpg  Poke Bowls                             Black bowl
# 5   burgart_205074_c70.jpg     Salades                          Crispy Caesar
# 6   burgart_205074_c70.jpg    Desserts                      Cheesecake maison
# 7   burgart_205074_c70.jpg    Desserts              Mousse au chocolat maison
# 8   burgart_205074_c70.jpg    Desserts  Fondant au chocolat artisan boulanger
# 9   burgart_205074_c70.jpg    Desserts            Financier artisan boulanger
# 17      Carte-in-seoul.png        Anju                         Mandoo (6 pcs)
#
#                                      Menu Ingredients  \
# 0   Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon,...
# 1   Bœuf (VBF Metzger), Cheddar, Sucrine, Bacon, T...
# 3   Filet de poulet, Tomme de Savoie IGP, Roquette...
# 4   Thon, Riz noir, Avocat, Oignon rouge, Cébette,...
# 5   Croquettes de poulet, Parmesan, Champignons br...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 17         Raviolis maison grillés au porc et légumes
#
#                            Closest JOW recipe by hand  \
# 0   [Blue Burger, French Burger, Classic Cheesebur...
# 1                 [Super Bacon Burger, Summer burger]
# 3                                            no match
# 4                    [Tuna bowl, Primavera Poke bowl]
# 5               [Salade César, Salade au poulet pané]
# 6                                          Cheesecake
# 7                           Mousse au chocolat maison
# 8                                 Fondant au chocolat
# 9   [Financier cerises noires & pistache, Financie...
# 17                                           no match
#
#                             Closest 7t recipe by hand
# 0                                            no match
# 1                                            no match
# 3   [awesome turkey burgers, blue cheese stuffed t...
# 4                                            no match
# 5   [better-for-you grilled chicken caesar salad, ...
# 6                                            no match
# 7   [chocolate mousse, chocolate dream mousse, raw...
# 8                                            no match
# 9                                            no match
# 17                                           no match

# %% [markdown]
# Check there is no more menu recipes with 'Not yet handled' in the column 'Closest JOW recipe by hand' or 'Closest 7t recipe by hand' and see how many menu recipes we have.

# %%
print("Number of not yet handled reicpes = ", menu_data[(menu_data['Closest JOW recipe by hand']=='Not yet handled') | (menu_data['Closest 7t recipe by hand']=='Not yet handled')].shape[0])
print("Total number of menu recipes = ", menu_data.shape[0])
print("Number of menu recipes with 'no match' with JOW = ", menu_data[menu_data['Closest JOW recipe by hand']=='no match'].shape[0])
print("Number of menu recipes with 'no match' with 7t = ", menu_data[menu_data['Closest 7t recipe by hand']=='no match'].shape[0])
print("Number of menu recipes with 'no match', neither with 7t, nor with JOW = ", menu_data[(menu_data['Closest 7t recipe by hand']=='no match') & (menu_data['Closest JOW recipe by hand']=='no match')].shape[0])
print("Number of menu recipes with 'match' with JOW = ", menu_data[menu_data['Closest JOW recipe by hand']!='no match'].shape[0])
print("Number of menu recipes with 'match' with 7t = ", menu_data[menu_data['Closest 7t recipe by hand']!='no match'].shape[0])
print("Number of menu recipes with 'match' with both JOW & 7t = ", menu_data[(menu_data['Closest 7t recipe by hand']!='no match') & (menu_data['Closest JOW recipe by hand']!='no match')].shape[0])
# Out:
# Number of not yet handled reicpes =  0
# Total number of menu recipes =  60
# Number of menu recipes with 'no match' with JOW =  16
# Number of menu recipes with 'no match' with 7t =  41
# Number of menu recipes with 'no match', neither with 7t, nor with JOW =  10
# Number of menu recipes with 'match' with JOW =  44
# Number of menu recipes with 'match' with 7t =  19
# Number of menu recipes with 'match' with both JOW & 7t =  13

# %% [markdown]
# Prepare the list of queries for test, first by concatenating the title and subtitle of menu recipes

# %%
menu_data['Menu Title and Subtitle'] = menu_data.apply(lambda row: row['Menu Title'] + ", " + row['Menu Subtitle'], axis = 1)
menu_data.head()
# Out:
#             Menu filename  Menu Title  Menu Subtitle  \
# 0  burgart_205074_c70.jpg     Burgers       Superfin
# 1  burgart_205074_c70.jpg     Burgers     Bon & Beau
# 3  burgart_205074_c70.jpg     Burgers  Green Chicken
# 4  burgart_205074_c70.jpg  Poke Bowls     Black bowl
# 5  burgart_205074_c70.jpg     Salades  Crispy Caesar
#
#                                     Menu Ingredients  \
# 0  Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon,...
# 1  Bœuf (VBF Metzger), Cheddar, Sucrine, Bacon, T...
# 3  Filet de poulet, Tomme de Savoie IGP, Roquette...
# 4  Thon, Riz noir, Avocat, Oignon rouge, Cébette,...
# 5  Croquettes de poulet, Parmesan, Champignons br...
#
#                           Closest JOW recipe by hand  \
# 0  [Blue Burger, French Burger, Classic Cheesebur...
# 1                [Super Bacon Burger, Summer burger]
# 3                                           no match
# 4                   [Tuna bowl, Primavera Poke bowl]
# 5              [Salade César, Salade au poulet pané]
#
#                            Closest 7t recipe by hand Menu Title and Subtitle
# 0                                           no match       Burgers, Superfin
# 1                                           no match     Burgers, Bon & Beau
# 3  [awesome turkey burgers, blue cheese stuffed t...  Burgers, Green Chicken
# 4                                           no match  Poke Bowls, Black bowl
# 5  [better-for-you grilled chicken caesar salad, ...  Salades, Crispy Caesar

# %% [markdown]
# Replace NaN in the ingredients column by empty string

# %%
menu_data = menu_data.fillna("")
menu_data.head()
# Out:
#             Menu filename  Menu Title  Menu Subtitle  \
# 0  burgart_205074_c70.jpg     Burgers       Superfin
# 1  burgart_205074_c70.jpg     Burgers     Bon & Beau
# 3  burgart_205074_c70.jpg     Burgers  Green Chicken
# 4  burgart_205074_c70.jpg  Poke Bowls     Black bowl
# 5  burgart_205074_c70.jpg     Salades  Crispy Caesar
#
#                                     Menu Ingredients  \
# 0  Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon,...
# 1  Bœuf (VBF Metzger), Cheddar, Sucrine, Bacon, T...
# 3  Filet de poulet, Tomme de Savoie IGP, Roquette...
# 4  Thon, Riz noir, Avocat, Oignon rouge, Cébette,...
# 5  Croquettes de poulet, Parmesan, Champignons br...
#
#                           Closest JOW recipe by hand  \
# 0  [Blue Burger, French Burger, Classic Cheesebur...
# 1                [Super Bacon Burger, Summer burger]
# 3                                           no match
# 4                   [Tuna bowl, Primavera Poke bowl]
# 5              [Salade César, Salade au poulet pané]
#
#                            Closest 7t recipe by hand Menu Title and Subtitle
# 0                                           no match       Burgers, Superfin
# 1                                           no match     Burgers, Bon & Beau
# 3  [awesome turkey burgers, blue cheese stuffed t...  Burgers, Green Chicken
# 4                                           no match  Poke Bowls, Black bowl
# 5  [better-for-you grilled chicken caesar salad, ...  Salades, Crispy Caesar

# %% [markdown]
# Do the same by concatenating the title, subtitle and ingredients of menu recipes

# %%
def add_ingredients(row):
    if row['Menu Ingredients']=='':
        res = row['Menu Title'] + ", " + row['Menu Subtitle']
    else:
        res = row['Menu Title'] + ", " + row['Menu Subtitle'] + ", " + row['Menu Ingredients']
    return res

menu_data['Menu all'] = menu_data.apply(add_ingredients, axis = 1)
menu_data.head(8)
# Out:
#             Menu filename  Menu Title                          Menu Subtitle  \
# 0  burgart_205074_c70.jpg     Burgers                               Superfin
# 1  burgart_205074_c70.jpg     Burgers                             Bon & Beau
# 3  burgart_205074_c70.jpg     Burgers                          Green Chicken
# 4  burgart_205074_c70.jpg  Poke Bowls                             Black bowl
# 5  burgart_205074_c70.jpg     Salades                          Crispy Caesar
# 6  burgart_205074_c70.jpg    Desserts                      Cheesecake maison
# 7  burgart_205074_c70.jpg    Desserts              Mousse au chocolat maison
# 8  burgart_205074_c70.jpg    Desserts  Fondant au chocolat artisan boulanger
#
#                                     Menu Ingredients  \
# 0  Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon,...
# 1  Bœuf (VBF Metzger), Cheddar, Sucrine, Bacon, T...
# 3  Filet de poulet, Tomme de Savoie IGP, Roquette...
# 4  Thon, Riz noir, Avocat, Oignon rouge, Cébette,...
# 5  Croquettes de poulet, Parmesan, Champignons br...
# 6
# 7
# 8
#
#                           Closest JOW recipe by hand  \
# 0  [Blue Burger, French Burger, Classic Cheesebur...
# 1                [Super Bacon Burger, Summer burger]
# 3                                           no match
# 4                   [Tuna bowl, Primavera Poke bowl]
# 5              [Salade César, Salade au poulet pané]
# 6                                         Cheesecake
# 7                          Mousse au chocolat maison
# 8                                Fondant au chocolat
#
#                            Closest 7t recipe by hand  \
# 0                                           no match
# 1                                           no match
# 3  [awesome turkey burgers, blue cheese stuffed t...
# 4                                           no match
# 5  [better-for-you grilled chicken caesar salad, ...
# 6                                           no match
# 7  [chocolate mousse, chocolate dream mousse, raw...
# 8                                           no match
#
#                            Menu Title and Subtitle  \
# 0                                Burgers, Superfin
# 1                              Burgers, Bon & Beau
# 3                           Burgers, Green Chicken
# 4                           Poke Bowls, Black bowl
# 5                           Salades, Crispy Caesar
# 6                      Desserts, Cheesecake maison
# 7              Desserts, Mousse au chocolat maison
# 8  Desserts, Fondant au chocolat artisan boulanger
#
#                                             Menu all
# 0  Burgers, Superfin, Bœuf (VBF Metzger), Comté A...
# 1  Burgers, Bon & Beau, Bœuf (VBF Metzger), Chedd...
# 3  Burgers, Green Chicken, Filet de poulet, Tomme...
# 4  Poke Bowls, Black bowl, Thon, Riz noir, Avocat...
# 5  Salades, Crispy Caesar, Croquettes de poulet, ...
# 6                        Desserts, Cheesecake maison
# 7                Desserts, Mousse au chocolat maison
# 8    Desserts, Fondant au chocolat artisan boulanger

# %% [markdown]
# **We keep only menu recipes that have been successfully matched -by hand- with either JOW or 7t recipes.**

# %%
menu_data_withmatch = menu_data[(menu_data['Closest 7t recipe by hand']!='no match') | (menu_data['Closest JOW recipe by hand']!='no match')]
print("Number of queries = ", menu_data_withmatch.shape[0])
# Out:
# Number of queries =  50

# %%
menu_data_withmatch
# Out:
#                                          Menu filename  \
# 0                               burgart_205074_c70.jpg
# 1                               burgart_205074_c70.jpg
# 3                               burgart_205074_c70.jpg
# 4                               burgart_205074_c70.jpg
# 5                               burgart_205074_c70.jpg
# 6                               burgart_205074_c70.jpg
# 7                               burgart_205074_c70.jpg
# 8                               burgart_205074_c70.jpg
# 9                               burgart_205074_c70.jpg
# 19                                  Carte-in-seoul.png
# 21                                  Carte-in-seoul.png
# 22                                  Carte-in-seoul.png
# 23                                  Carte-in-seoul.png
# 25                                  Carte-in-seoul.png
# 26                                  Carte-in-seoul.png
# 27   Carte-Restaurant-Nelsons-Paris-Jour-2-1024x724...
# 28   Carte-Restaurant-Nelsons-Paris-Jour-2-1024x724...
# 29   Carte-Restaurant-Nelsons-Paris-Jour-2-1024x724...
# 32   Carte-Restaurant-Nelsons-Paris-Jour-2-1024x724...
# 33   Carte-Restaurant-Nelsons-Paris-Jour-2-1024x724...
# 37            feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg
# 40            feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg
# 41            feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg
# 42            feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg
# 43            feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg
# 44            feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg
# 45            feaa6c7b-9b16-4d51-b71d-75518f16cb08.jpg
# 48                      in-bocca-al-lupo_42356_293.jpg
# 49                      in-bocca-al-lupo_42356_293.jpg
# 50                      in-bocca-al-lupo_42356_293.jpg
# 51                      in-bocca-al-lupo_42356_293.jpg
# 52                      in-bocca-al-lupo_42356_293.jpg
# 53                      in-bocca-al-lupo_42356_293.jpg
# 55                                      menu_bobby.jpg
# 57                                      menu_bobby.jpg
# 58                                      menu_bobby.jpg
# 59                                      menu_bobby.jpg
# 60                                      menu_bobby.jpg
# 61                                      menu_bobby.jpg
# 63                                      menu_bobby.jpg
# 66                           menu-PNY-BURGER-GAITE.jpg
# 67                                           pasta.jpg
# 69                                           pasta.jpg
# 71                                           pasta.jpg
# 72                                           pasta.jpg
# 76                            fabbrezza_202084_665.jpg
# 78                            fabbrezza_202084_665.jpg
# 116                                       IMG_7930.PNG
# 124                                       IMG_7934.PNG
# 125                                       IMG_7934.PNG
#
#                           Menu Title  \
# 0                            Burgers
# 1                            Burgers
# 3                            Burgers
# 4                         Poke Bowls
# 5                            Salades
# 6                           Desserts
# 7                           Desserts
# 8                           Desserts
# 9                           Desserts
# 19                              Anju
# 21                           Chicken
# 22                        Classiques
# 23                        Classiques
# 25                          Nouilles
# 26                          Nouilles
# 27                           Salades
# 28                           Salades
# 29                           Salades
# 32                    Végé pour tous
# 33                    Végé pour tous
# 37                          Starters
# 40                             Mains
# 41                             Mains
# 42                    Hox Signatures
# 43                    Hox Signatures
# 44                             Sides
# 45                             Sides
# 48   Pizza Bambini (pour les petits)
# 49   Pizza Bambini (pour les petits)
# 50                          Planches
# 51                          Insalata
# 52                          Desserts
# 53                          Desserts
# 55      Petites assiettes à partager
# 57                             Pizz'
# 58                             Pizz'
# 59                      Pasta Fresca
# 60                      Pasta Fresca
# 61                      Pasta Fresca
# 63                             Dolci
# 66             Hamburgers de qualité
# 67                             Pasta
# 69                             Pasta
# 71                             Pasta
# 72                             Pasta
# 76                     Plat au choix
# 78                     Plat au choix
# 116                        Les plats
# 124                            Plats
# 125                            Plats
#
#                                          Menu Subtitle  \
# 0                                             Superfin
# 1                                           Bon & Beau
# 3                                        Green Chicken
# 4                                           Black bowl
# 5                                        Crispy Caesar
# 6                                    Cheesecake maison
# 7                            Mousse au chocolat maison
# 8                Fondant au chocolat artisan boulanger
# 9                          Financier artisan boulanger
# 19                             Sewoo kkanpoong (8 pcs)
# 21              YangNyeom chicken (5pcs, 12pcs, 24pcs)
# 22                                             Bulgogi
# 23                                               Jeyuk
# 25                            Japchae - bœuf ou tofu -
# 26                                         Jjajan myun
# 27                                            La César
# 28                           La Biquette de Rocamadour
# 29                                           Végé Bowl
# 32                                   Risotto primavera
# 33                              Truffade des montagnes
# 37                  Gaspacho tomate, pastèque et crabe
# 40                               Paris London Rumsteak
# 41                                         Miso Salmon
# 42                                    Hox Cheeseburger
# 43                           Beyond meat veggie burger
# 44                                              Frites
# 45                                 Frites patate douce
# 48                                          Margherita
# 49                                          Prosciutto
# 50                                        Salumi misti
# 51                                               Mista
# 52                                            Tiramisù
# 53   Panna cotta (avec gousses de vanille) et couli...
# 55                                        Gros raviolo
# 57                                             Quattro
# 58                                            Zucchine
# 59                                              Limone
# 60                                               Norma
# 61                                            Carbobby
# 63                                      Boozy tiramisù
# 66                                Vegan Forest Nirvana
# 67                        Penne Al Pomodoro E Basilico
# 69                            Spaghetti Alla Bolognese
# 71                                 Linguine Al Salmone
# 72                                  Penne Al Formaggio
# 76                                    Pizza Margherita
# 78                            "Petit" Lasagne de Tonia
# 116  Canard, purée de cresson, pommes boulangères, ...
# 124                                        Tartiflette
# 125                           Saucisse - Purée truffée
#
#                                       Menu Ingredients  \
# 0    Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon,...
# 1    Bœuf (VBF Metzger), Cheddar, Sucrine, Bacon, T...
# 3    Filet de poulet, Tomme de Savoie IGP, Roquette...
# 4    Thon, Riz noir, Avocat, Oignon rouge, Cébette,...
# 5    Croquettes de poulet, Parmesan, Champignons br...
# 6
# 7
# 8
# 9
# 19         Crevettes frites dans une sauce aigre douce
# 21                Poulet frit enrobé de sauce + salade
# 22           Bœuf émincé à la sauce soja, légumes, riz
# 23          Porc sauté, légumes, riz - soja ou piquant
# 25   Nouilles de papate douce, légumes, boeuf ou to...
# 26   Nouille à la sauce noir jjajan, légume accomag...
# 27   poulet grillé, tomates cerise, œuf, romaine, p...
# 28                              mielleuse et craquante
# 29   avocat, choux kale frit, concombre, edamame, r...
# 32                   asperges, artichaut et petit pois
# 33                                              salade
# 37         Tomato, watermelon, coriander and chive oil
# 40   (240g) French beef, onion rings, café de Paris...
# 41    Raw and cooked white asparagus, artichoke mousse
# 42   Spanish beef, cheddar, caramelized onions, fri...
# 43   Beyond Meat pattie, charcoal bun, avocado, fri...
# 44                                                 (v)
# 45               Parmesan cheese, rosemary, spicy mayo
# 48                            sauce tomate, mozzarella
# 49                    sauce tomate, mozzarella, jambon
# 50              assortiment de charcuteries italiennes
# 51   roquette, mozzarella di bufala, artichauts, ja...
# 52
# 53
# 55       aux champis d'une ferme urbaine du 18è siècle
# 57   Mozza fior di latte et scamorza IDF, gorgonzol...
# 58   Crème de courgette,  mozza fior di latte IDF, ...
# 59   Trenette, sauce au citron, piment (ou non si v...
# 60   Tagliatelle, sauce tomate et aubergines frites...
# 61   Spaghetti, crème d'œuf bio et de pecorino, gua...
# 63    Tiramisù classique + Amaretto (liqueur d'amande)
# 66   Pain vegan, steak végétal "Les nouveaux Fermie...
# 67                                     Tomate, basilic
# 69                              Tomate, viande de bœuf
# 71                          Crème fraîche, saumon fumé
# 72                              Gorgonzola, parmigiano
# 76
# 78
# 116
# 124  Reblochon, pommes de terre, oignons, poitrine ...
# 125  Saucisse d'Auvergne, purée à la truffe, crème ...
#
#                             Closest JOW recipe by hand  \
# 0    [Blue Burger, French Burger, Classic Cheesebur...
# 1                  [Super Bacon Burger, Summer burger]
# 3                                             no match
# 4                     [Tuna bowl, Primavera Poke bowl]
# 5                [Salade César, Salade au poulet pané]
# 6                                           Cheesecake
# 7                            Mousse au chocolat maison
# 8                                  Fondant au chocolat
# 9    [Financier cerises noires & pistache, Financie...
# 19         [Crevettes teriyaki, Crevettes miel sésame]
# 21                                            no match
# 22   [Wok de bœuf légumes croquants, Bœuf thaï, Bœu...
# 23                                     Porc au caramel
# 25                            Nouilles sautées au bœuf
# 26   [Nouilles sautées aux légumes d'été, Nouilles ...
# 27                                        Salade César
# 28   [Salade de chèvre chaud, Salade chèvre, miel &...
# 29                                     Vegan poke bowl
# 32                                Risotto aux asperges
# 33                                 Tartiflette express
# 37                    Gaspacho repas crevette & avocat
# 40                                            no match
# 41                             Saumon & asperges rôtis
# 42                                Classic Cheeseburger
# 43                                 Cheeseburger veggie
# 44                                            no match
# 45                                            no match
# 48                                    Pizza Margherita
# 49                                         Pizza Parma
# 50                              Planche de charcuterie
# 51   [Salade jambon cru, mozza & pistaches, Insalat...
# 52                                            Tiramisu
# 53                             Panna cotta à la fraise
# 55   [Raviolis à la crème de champignons, Raviolis ...
# 57                             Pizza maison 3 fromages
# 58                          Pizza verde à la courgette
# 59                                     Pasta al limone
# 60                                    Pasta alla Norma
# 61                                Pasta alla carbonara
# 63                                            Tiramisu
# 66                                 Cheeseburger veggie
# 67     [Cherry tomatoes spaghetti, Tomato vegan pasta]
# 69   [Spaghetti alla bolognese express, Spaghetti b...
# 71   [Linguine saumon & petits pois, Pasta saumon c...
# 72                                            no match
# 76                                    Pizza Margherita
# 78                             Lasagnes alla bolognese
# 116   [Parmentier de canard, Magret de canard & purée]
# 124                                Tartiflette express
# 125  [Saucisse & purée maison, Saucisse purée & épi...
#
#                              Closest 7t recipe by hand  \
# 0                                             no match
# 1                                             no match
# 3    [awesome turkey burgers, blue cheese stuffed t...
# 4                                             no match
# 5    [better-for-you grilled chicken caesar salad, ...
# 6                                             no match
# 7    [chocolate mousse, chocolate dream mousse, raw...
# 8                                             no match
# 9                                             no match
# 19                                            no match
# 21                                  korean bbq chicken
# 22                 beef bulgogi(korean marinated beef)
# 23                                  thai pork stir fry
# 25                                            no match
# 26                                            no match
# 27   [better-for-you grilled chicken caesar salad, ...
# 28                         [waldorf goat cheese salad]
# 29                             tofu, kale, and raisins
# 32                                            no match
# 33   [blue cheese potato gratin recipe, potato and ...
# 37                                            no match
# 40                               barbecued flank steak
# 41                                            no match
# 42                                            no match
# 43   [amara veggie burgers, the woodward veggie bur...
# 44                       perfectly simple french fries
# 45   [sweet potato fries, sweet-hot bbq tater fries...
# 48                                            no match
# 49                                            no match
# 50                                            no match
# 51                                            no match
# 52                                            no match
# 53                                            no match
# 55                                            no match
# 57                                            no match
# 58                                            no match
# 59   [lemon basil spaghetti, lemon butter parmesan ...
# 60                                            no match
# 61                                            no match
# 63                                            no match
# 66                                        tofu burgers
# 67                                            no match
# 69                                            no match
# 71                                            no match
# 72                                     roquefort pasta
# 76                                            no match
# 78                                            no match
# 116                                           no match
# 124  [blue cheese potato gratin recipe, potato and ...
# 125  [sweet potatoes with pecans & sausage, sweet p...
#
#                                Menu Title and Subtitle  \
# 0                                    Burgers, Superfin
# 1                                  Burgers, Bon & Beau
# 3                               Burgers, Green Chicken
# 4                               Poke Bowls, Black bowl
# 5                               Salades, Crispy Caesar
# 6                          Desserts, Cheesecake maison
# 7                  Desserts, Mousse au chocolat maison
# 8      Desserts, Fondant au chocolat artisan boulanger
# 9                Desserts, Financier artisan boulanger
# 19                       Anju, Sewoo kkanpoong (8 pcs)
# 21     Chicken, YangNyeom chicken (5pcs, 12pcs, 24pcs)
# 22                                 Classiques, Bulgogi
# 23                                   Classiques, Jeyuk
# 25                  Nouilles, Japchae - bœuf ou tofu -
# 26                               Nouilles, Jjajan myun
# 27                                   Salades, La César
# 28                  Salades, La Biquette de Rocamadour
# 29                                  Salades, Végé Bowl
# 32                   Végé pour tous, Risotto primavera
# 33              Végé pour tous, Truffade des montagnes
# 37        Starters, Gaspacho tomate, pastèque et crabe
# 40                        Mains, Paris London Rumsteak
# 41                                  Mains, Miso Salmon
# 42                    Hox Signatures, Hox Cheeseburger
# 43           Hox Signatures, Beyond meat veggie burger
# 44                                       Sides, Frites
# 45                          Sides, Frites patate douce
# 48         Pizza Bambini (pour les petits), Margherita
# 49         Pizza Bambini (pour les petits), Prosciutto
# 50                              Planches, Salumi misti
# 51                                     Insalata, Mista
# 52                                  Desserts, Tiramisù
# 53   Desserts, Panna cotta (avec gousses de vanille...
# 55          Petites assiettes à partager, Gros raviolo
# 57                                      Pizz', Quattro
# 58                                     Pizz', Zucchine
# 59                                Pasta Fresca, Limone
# 60                                 Pasta Fresca, Norma
# 61                              Pasta Fresca, Carbobby
# 63                               Dolci, Boozy tiramisù
# 66         Hamburgers de qualité, Vegan Forest Nirvana
# 67                 Pasta, Penne Al Pomodoro E Basilico
# 69                     Pasta, Spaghetti Alla Bolognese
# 71                          Pasta, Linguine Al Salmone
# 72                           Pasta, Penne Al Formaggio
# 76                     Plat au choix, Pizza Margherita
# 78             Plat au choix, "Petit" Lasagne de Tonia
# 116  Les plats, Canard, purée de cresson, pommes bo...
# 124                                 Plats, Tartiflette
# 125                    Plats, Saucisse - Purée truffée
#
#                                               Menu all
# 0    Burgers, Superfin, Bœuf (VBF Metzger), Comté A...
# 1    Burgers, Bon & Beau, Bœuf (VBF Metzger), Chedd...
# 3    Burgers, Green Chicken, Filet de poulet, Tomme...
# 4    Poke Bowls, Black bowl, Thon, Riz noir, Avocat...
# 5    Salades, Crispy Caesar, Croquettes de poulet, ...
# 6                          Desserts, Cheesecake maison
# 7                  Desserts, Mousse au chocolat maison
# 8      Desserts, Fondant au chocolat artisan boulanger
# 9                Desserts, Financier artisan boulanger
# 19   Anju, Sewoo kkanpoong (8 pcs), Crevettes frite...
# 21   Chicken, YangNyeom chicken (5pcs, 12pcs, 24pcs...
# 22   Classiques, Bulgogi, Bœuf émincé à la sauce so...
# 23   Classiques, Jeyuk, Porc sauté, légumes, riz - ...
# 25   Nouilles, Japchae - bœuf ou tofu -, Nouilles d...
# 26   Nouilles, Jjajan myun, Nouille à la sauce noir...
# 27   Salades, La César, poulet grillé, tomates ceri...
# 28   Salades, La Biquette de Rocamadour, mielleuse ...
# 29   Salades, Végé Bowl, avocat, choux kale frit, c...
# 32   Végé pour tous, Risotto primavera, asperges, a...
# 33      Végé pour tous, Truffade des montagnes, salade
# 37   Starters, Gaspacho tomate, pastèque et crabe, ...
# 40   Mains, Paris London Rumsteak, (240g) French be...
# 41   Mains, Miso Salmon, Raw and cooked white aspar...
# 42   Hox Signatures, Hox Cheeseburger, Spanish beef...
# 43   Hox Signatures, Beyond meat veggie burger, Bey...
# 44                                  Sides, Frites, (v)
# 45   Sides, Frites patate douce, Parmesan cheese, r...
# 48   Pizza Bambini (pour les petits), Margherita, s...
# 49   Pizza Bambini (pour les petits), Prosciutto, s...
# 50   Planches, Salumi misti, assortiment de charcut...
# 51   Insalata, Mista, roquette, mozzarella di bufal...
# 52                                  Desserts, Tiramisù
# 53   Desserts, Panna cotta (avec gousses de vanille...
# 55   Petites assiettes à partager, Gros raviolo, au...
# 57   Pizz', Quattro, Mozza fior di latte et scamorz...
# 58   Pizz', Zucchine, Crème de courgette,  mozza fi...
# 59   Pasta Fresca, Limone, Trenette, sauce au citro...
# 60   Pasta Fresca, Norma, Tagliatelle, sauce tomate...
# 61   Pasta Fresca, Carbobby, Spaghetti, crème d'œuf...
# 63   Dolci, Boozy tiramisù, Tiramisù classique + Am...
# 66   Hamburgers de qualité, Vegan Forest Nirvana, P...
# 67   Pasta, Penne Al Pomodoro E Basilico, Tomate, b...
# 69   Pasta, Spaghetti Alla Bolognese, Tomate, viand...
# 71   Pasta, Linguine Al Salmone, Crème fraîche, sau...
# 72   Pasta, Penne Al Formaggio, Gorgonzola, parmigiano
# 76                     Plat au choix, Pizza Margherita
# 78             Plat au choix, "Petit" Lasagne de Tonia
# 116  Les plats, Canard, purée de cresson, pommes bo...
# 124  Plats, Tartiflette, Reblochon, pommes de terre...
# 125  Plats, Saucisse - Purée truffée, Saucisse d'Au...

# %% [markdown]
# ## Import and prepare the JOW database

# %%
jow_data = pd.read_json(data_path + 'data/Recipes/recipes_jow.json')
jow_data = jow_data.transpose()
pd.set_option('display.max_colwidth', None)
jow_data['recipe_name'] = jow_data.index
jow_data.head()
# Out:
#                                  cuisson  \
# Yakitori bœuf fromage         10 minutes
# Gnocchis Epinards Gorgonzola   5 minutes
# Dahl de lentilles corail      plat froid
# Veggie lasagna                50 minutes
# Pasta alla carbonara           9 minutes
#
#                                                                                                                                                          ingredients  \
# Yakitori bœuf fromage                                     [[80 g, Bœuf (carpaccio)], [100 g, Emmental], [1 càs, Sauce Teriyaki], [70 g, Riz], [6, Pics à brochette]]
# Gnocchis Epinards Gorgonzola                                                 [[150 g, Gnocchi], [100 g, Epinard (frais)], [30 g, Gorgonzola], [5 cl, Crème liquide]]
# Dahl de lentilles corail                                                   [[50 g, Lentilles corail], [80 g, Tomate (chair)], [5 cl, Lait de coco], [1/2 gou., Ail]]
# Veggie lasagna                [[50 g, Lasagnes (cru)], [150 g, Courgette], [150 g, Tomate (purée)], [80 g, Champignons de Paris (frais)], [1/2, Mozzarella (boule)]]
# Pasta alla carbonara                                                        [[100 g, Pâtes (spaghetti)], [3 tran., Pancetta], [1, Œuf], [40 g, Parmesan (morceaux)]]
#
#                                                recipe_name
# Yakitori bœuf fromage                Yakitori bœuf fromage
# Gnocchis Epinards Gorgonzola  Gnocchis Epinards Gorgonzola
# Dahl de lentilles corail          Dahl de lentilles corail
# Veggie lasagna                              Veggie lasagna
# Pasta alla carbonara                  Pasta alla carbonara

# %% [markdown]
# We remove ligatures, e.g. Bœuf -> Boeuf.
# This is probably useless.

# %%
REGEX_REPLACEMENTS = [(r"\u0153", "oe"), \
                      (r"\u0152", "Oe")]

def remove_ligatures(transcript):
    for old, new in REGEX_REPLACEMENTS:
        transcript = re.sub(old, new, transcript, flags=re.IGNORECASE)
    return transcript

#jow_data['recipe_name'] = jow_data['recipe_name'].apply(lambda s: remove_ligatures(str(s)))
jow_data = jow_data.rename({'ingredients': 'ingredients_with_quantity'}, axis = 1)
jow_data.head()
# Out:
#                                  cuisson  \
# Yakitori bœuf fromage         10 minutes
# Gnocchis Epinards Gorgonzola   5 minutes
# Dahl de lentilles corail      plat froid
# Veggie lasagna                50 minutes
# Pasta alla carbonara           9 minutes
#
#                                                                                                                                            ingredients_with_quantity  \
# Yakitori bœuf fromage                                     [[80 g, Bœuf (carpaccio)], [100 g, Emmental], [1 càs, Sauce Teriyaki], [70 g, Riz], [6, Pics à brochette]]
# Gnocchis Epinards Gorgonzola                                                 [[150 g, Gnocchi], [100 g, Epinard (frais)], [30 g, Gorgonzola], [5 cl, Crème liquide]]
# Dahl de lentilles corail                                                   [[50 g, Lentilles corail], [80 g, Tomate (chair)], [5 cl, Lait de coco], [1/2 gou., Ail]]
# Veggie lasagna                [[50 g, Lasagnes (cru)], [150 g, Courgette], [150 g, Tomate (purée)], [80 g, Champignons de Paris (frais)], [1/2, Mozzarella (boule)]]
# Pasta alla carbonara                                                        [[100 g, Pâtes (spaghetti)], [3 tran., Pancetta], [1, Œuf], [40 g, Parmesan (morceaux)]]
#
#                                                recipe_name
# Yakitori bœuf fromage                Yakitori bœuf fromage
# Gnocchis Epinards Gorgonzola  Gnocchis Epinards Gorgonzola
# Dahl de lentilles corail          Dahl de lentilles corail
# Veggie lasagna                              Veggie lasagna
# Pasta alla carbonara                  Pasta alla carbonara

# %% [markdown]
# Let's add a column for ingredients only (no quantity, informations in parenthesis are removed)

# %%
# Known from previous notebook '[Genevieve] ingredients_scores__process.ipynb'
meaningless_jow_ingredients = ['1/10 bou.', '1/5 bou.', '1/50 bou.', '6 pinc.', '1 càc', '1/4', '3 pinc.', '2 càs', \
                               '1 cm', '1/20 bou.', '1 càs', '1/2 càc', 'Papier cuisson', 'Pics à brochette']

def extract_ingredients(row):
    ingredients = []
    for x in row:
        if len(x)>1:         
            ingredient = x[-1]    # the ingredient is the last element of the list 'row'  
            if ingredient not in meaningless_jow_ingredients:   # keep only meaningfull ingredients
                ingredient = remove_ligatures(ingredient)
                ingredients.append(ingredient) 

    ingredients = [re.sub("[\(\[].*?[\)\]]", "", ingredient) for ingredient in ingredients]  #remove informations in parenthesis
    # remove blank at the end of the string that remained when parenthesis have been removed
    ingredients = [ing[:-1] if ing[-1]==" " else ing for ing in ingredients]   

    return ingredients

jow_data['ingredients'] = jow_data['ingredients_with_quantity'].apply(extract_ingredients)
jow_data.head()
# Out:
#                                  cuisson  \
# Yakitori bœuf fromage         10 minutes
# Gnocchis Epinards Gorgonzola   5 minutes
# Dahl de lentilles corail      plat froid
# Veggie lasagna                50 minutes
# Pasta alla carbonara           9 minutes
#
#                                                                                                                                            ingredients_with_quantity  \
# Yakitori bœuf fromage                                     [[80 g, Bœuf (carpaccio)], [100 g, Emmental], [1 càs, Sauce Teriyaki], [70 g, Riz], [6, Pics à brochette]]
# Gnocchis Epinards Gorgonzola                                                 [[150 g, Gnocchi], [100 g, Epinard (frais)], [30 g, Gorgonzola], [5 cl, Crème liquide]]
# Dahl de lentilles corail                                                   [[50 g, Lentilles corail], [80 g, Tomate (chair)], [5 cl, Lait de coco], [1/2 gou., Ail]]
# Veggie lasagna                [[50 g, Lasagnes (cru)], [150 g, Courgette], [150 g, Tomate (purée)], [80 g, Champignons de Paris (frais)], [1/2, Mozzarella (boule)]]
# Pasta alla carbonara                                                        [[100 g, Pâtes (spaghetti)], [3 tran., Pancetta], [1, Œuf], [40 g, Parmesan (morceaux)]]
#
#                                                recipe_name  \
# Yakitori bœuf fromage                Yakitori bœuf fromage
# Gnocchis Epinards Gorgonzola  Gnocchis Epinards Gorgonzola
# Dahl de lentilles corail          Dahl de lentilles corail
# Veggie lasagna                              Veggie lasagna
# Pasta alla carbonara                  Pasta alla carbonara
#
#                                                                                   ingredients
# Yakitori bœuf fromage                                  [Boeuf, Emmental, Sauce Teriyaki, Riz]
# Gnocchis Epinards Gorgonzola                    [Gnocchi, Epinard, Gorgonzola, Crème liquide]
# Dahl de lentilles corail                        [Lentilles corail, Tomate, Lait de coco, Ail]
# Veggie lasagna                [Lasagnes, Courgette, Tomate, Champignons de Paris, Mozzarella]
# Pasta alla carbonara                                        [Pâtes, Pancetta, oeuf, Parmesan]

# %% [markdown]
# Add the column 'name_with_ingredients' by concatenating recipe names and ingredients

# %%
jow_data['name_with_ingredients'] = jow_data.apply(lambda row: row['recipe_name'] + ", " + ', '.join(row['ingredients']), axis = 1)
jow_data.head(2)
# Out:
#                                  cuisson  \
# Yakitori bœuf fromage         10 minutes
# Gnocchis Epinards Gorgonzola   5 minutes
#
#                                                                                                                ingredients_with_quantity  \
# Yakitori bœuf fromage         [[80 g, Bœuf (carpaccio)], [100 g, Emmental], [1 càs, Sauce Teriyaki], [70 g, Riz], [6, Pics à brochette]]
# Gnocchis Epinards Gorgonzola                     [[150 g, Gnocchi], [100 g, Epinard (frais)], [30 g, Gorgonzola], [5 cl, Crème liquide]]
#
#                                                recipe_name  \
# Yakitori bœuf fromage                Yakitori bœuf fromage
# Gnocchis Epinards Gorgonzola  Gnocchis Epinards Gorgonzola
#
#                                                                 ingredients  \
# Yakitori bœuf fromage                [Boeuf, Emmental, Sauce Teriyaki, Riz]
# Gnocchis Epinards Gorgonzola  [Gnocchi, Epinard, Gorgonzola, Crème liquide]
#
#                                                                                   name_with_ingredients
# Yakitori bœuf fromage                       Yakitori bœuf fromage, Boeuf, Emmental, Sauce Teriyaki, Riz
# Gnocchis Epinards Gorgonzola  Gnocchis Epinards Gorgonzola, Gnocchi, Epinard, Gorgonzola, Crème liquide

# %% [markdown]
# ##Import the 7t recipe database translated in french

# %%
seven_path = data_path + 'data/Recipes/recettes_completes_7tomorrow_preprocessed.json'
seven_data = pd.read_json(seven_path)
seven_data.head()
# Out:
#                                                 title_raw  \
# 0                               " child's play" sour pops
# 1                                    " fried egg sundaes"
# 2  " world's best "( and easiest ) teriyaki chicken wings
# 3                 "apple crisp" peanut butter snack bites
# 4                                   "berry good" smoothie
#
#                                                      title_raw_fr  \
# 0                                    "Play de l'enfant" Sour Pops
# 1                                      "Sundaes aux œufs au plat"
# 2  "Best du monde" (et les plus faciles) Ailes de poulet Teriyaki
# 3  Bites de collations au beurre d'arachide "pomme croustillante"
# 4                                           Smoothie "Berry Good"
#
#                                              ingredient_basics  \
# 0                                    [lime juice, lemon juice]
# 1                                    [ice cream, cream, spice]
# 2                             [chicken, soy sauce  soy, sugar]
# 3               [peanut butter, honey, oat, nut, apple, spice]
# 4  [apple juice, strawberry, raspberry, blackberry, blueberry]
#
#                                      ingredient_basics_fr  \
# 0                     [jus de citron vert, jus de citron]
# 1                                  [glace, crème, épices]
# 2                       [poulet, sauce de soja, du sucre]
# 3  [beurre d'arachide, miel, avoine, noix, Pomme, épices]
# 4    [jus de pomme, fraise, framboise, la mûre, myrtille]
#
#                                                                                                ingredient_basics_with_qty  \
# 0                                                                         [[726.0 g, lime juice], [732.0 g, lemon juice]]
# 1                                                                [[1584.0 g, ice cream], [50.0 g, cream], [5.1 g, spice]]
# 2                                                    [[2267.96 g, chicken], [283.5 g, soy sauce  soy], [453.59 g, sugar]]
# 3           [[128.0 g, peanut butter], [84.75 g, honey], [156.0 g, oat], [58.5 g, nut], [41.67 g, apple], [1.3 g, spice]]
# 4  [[372.0 g, apple juice], [1824.0 g, strawberry], [1476.0 g, raspberry], [2016.0 g, blackberry], [2072.0 g, blueberry]]
#
#                                                                                            ingredient_basics_with_qty_fr
# 0                                                              [[726.0 g, jus de citron vert], [732.0 g, jus de citron]]
# 1                                                                  [[1584.0 g, glace], [50.0 g, crème], [5.1 g, épices]]
# 2                                                  [[2267.96 g, poulet], [283.5 g, sauce de soja], [453.59 g, du sucre]]
# 3  [[128.0 g, beurre d'arachide], [84.75 g, miel], [156.0 g, avoine], [58.5 g, noix], [41.67 g, Pomme], [1.3 g, épices]]
# 4        [[372.0 g, jus de pomme], [1824.0 g, fraise], [1476.0 g, framboise], [2016.0 g, la mûre], [2072.0 g, myrtille]]

# %% [markdown]
# Remove doublons in ingredient lists

# %%
seven_data['ingredient_basics'] = seven_data['ingredient_basics'].apply(lambda l: list(set(l)))    
seven_data['ingredient_basics_fr'] = seven_data['ingredient_basics_fr'].apply(lambda l: list(set(l)))

# %%
seven_data.head(2)
# Out:
#                    title_raw                  title_raw_fr  \
# 0  " child's play" sour pops  "Play de l'enfant" Sour Pops
# 1       " fried egg sundaes"    "Sundaes aux œufs au plat"
#
#            ingredient_basics                 ingredient_basics_fr  \
# 0  [lime juice, lemon juice]  [jus de citron, jus de citron vert]
# 1  [cream, ice cream, spice]               [épices, crème, glace]
#
#                                  ingredient_basics_with_qty  \
# 0           [[726.0 g, lime juice], [732.0 g, lemon juice]]
# 1  [[1584.0 g, ice cream], [50.0 g, cream], [5.1 g, spice]]
#
#                                ingredient_basics_with_qty_fr
# 0  [[726.0 g, jus de citron vert], [732.0 g, jus de citron]]
# 1      [[1584.0 g, glace], [50.0 g, crème], [5.1 g, épices]]

# %% [markdown]
# Concatenate recipe names and ingredients

# %%
seven_data['name_with_ingredients'] = seven_data.apply(lambda row: row['title_raw'] + ", " + ', '.join(row['ingredient_basics']), axis = 1)        
seven_data['name_with_ingredients_fr'] = seven_data.apply(lambda row: row['title_raw_fr'] + ", " +  ', '.join(row['ingredient_basics_fr']), axis = 1)

# %%
seven_data.head()
# Out:
#                                                 title_raw  \
# 0                               " child's play" sour pops
# 1                                    " fried egg sundaes"
# 2  " world's best "( and easiest ) teriyaki chicken wings
# 3                 "apple crisp" peanut butter snack bites
# 4                                   "berry good" smoothie
#
#                                                      title_raw_fr  \
# 0                                    "Play de l'enfant" Sour Pops
# 1                                      "Sundaes aux œufs au plat"
# 2  "Best du monde" (et les plus faciles) Ailes de poulet Teriyaki
# 3  Bites de collations au beurre d'arachide "pomme croustillante"
# 4                                           Smoothie "Berry Good"
#
#                                              ingredient_basics  \
# 0                                    [lime juice, lemon juice]
# 1                                    [cream, ice cream, spice]
# 2                             [soy sauce  soy, chicken, sugar]
# 3               [honey, nut, spice, apple, peanut butter, oat]
# 4  [blueberry, apple juice, blackberry, raspberry, strawberry]
#
#                                      ingredient_basics_fr  \
# 0                     [jus de citron, jus de citron vert]
# 1                                  [épices, crème, glace]
# 2                       [sauce de soja, du sucre, poulet]
# 3  [épices, noix, Pomme, miel, avoine, beurre d'arachide]
# 4    [framboise, fraise, myrtille, jus de pomme, la mûre]
#
#                                                                                                ingredient_basics_with_qty  \
# 0                                                                         [[726.0 g, lime juice], [732.0 g, lemon juice]]
# 1                                                                [[1584.0 g, ice cream], [50.0 g, cream], [5.1 g, spice]]
# 2                                                    [[2267.96 g, chicken], [283.5 g, soy sauce  soy], [453.59 g, sugar]]
# 3           [[128.0 g, peanut butter], [84.75 g, honey], [156.0 g, oat], [58.5 g, nut], [41.67 g, apple], [1.3 g, spice]]
# 4  [[372.0 g, apple juice], [1824.0 g, strawberry], [1476.0 g, raspberry], [2016.0 g, blackberry], [2072.0 g, blueberry]]
#
#                                                                                            ingredient_basics_with_qty_fr  \
# 0                                                              [[726.0 g, jus de citron vert], [732.0 g, jus de citron]]
# 1                                                                  [[1584.0 g, glace], [50.0 g, crème], [5.1 g, épices]]
# 2                                                  [[2267.96 g, poulet], [283.5 g, sauce de soja], [453.59 g, du sucre]]
# 3  [[128.0 g, beurre d'arachide], [84.75 g, miel], [156.0 g, avoine], [58.5 g, noix], [41.67 g, Pomme], [1.3 g, épices]]
# 4        [[372.0 g, jus de pomme], [1824.0 g, fraise], [1476.0 g, framboise], [2016.0 g, la mûre], [2072.0 g, myrtille]]
#
#                                                                     name_with_ingredients  \
# 0                                      " child's play" sour pops, lime juice, lemon juice
# 1                                           " fried egg sundaes", cream, ice cream, spice
# 2  " world's best "( and easiest ) teriyaki chicken wings, soy sauce  soy, chicken, sugar
# 3   "apple crisp" peanut butter snack bites, honey, nut, spice, apple, peanut butter, oat
# 4        "berry good" smoothie, blueberry, apple juice, blackberry, raspberry, strawberry
#
#                                                                                                name_with_ingredients_fr
# 0                                                       "Play de l'enfant" Sour Pops, jus de citron, jus de citron vert
# 1                                                                      "Sundaes aux œufs au plat", épices, crème, glace
# 2                       "Best du monde" (et les plus faciles) Ailes de poulet Teriyaki, sauce de soja, du sucre, poulet
# 3  Bites de collations au beurre d'arachide "pomme croustillante", épices, noix, Pomme, miel, avoine, beurre d'arachide
# 4                                             Smoothie "Berry Good", framboise, fraise, myrtille, jus de pomme, la mûre

# %% [markdown]
# Rename the columns to be consistent with JOW

# %%
dict_rename = {'ingredient_basics_with_qty': 'ingredients_with_quantity_en', \
               'ingredient_basics_with_qty_fr': 'ingredients_with_quantity', \
               'title_raw': 'recipe_name_en', \
               'title_raw_fr': 'recipe_name', \
               'ingredient_basics': 'ingredients_en', \
               'ingredient_basics_fr': 'ingredients', \
               'name_with_ingredients': 'name_with_ingredients_en', \
               'name_with_ingredients_fr': 'name_with_ingredients'}

seven_data = seven_data.rename(dict_rename, axis = 1)
seven_data.head(2)
# Out:
#               recipe_name_en                   recipe_name  \
# 0  " child's play" sour pops  "Play de l'enfant" Sour Pops
# 1       " fried egg sundaes"    "Sundaes aux œufs au plat"
#
#               ingredients_en                          ingredients  \
# 0  [lime juice, lemon juice]  [jus de citron, jus de citron vert]
# 1  [cream, ice cream, spice]               [épices, crème, glace]
#
#                                ingredients_with_quantity_en  \
# 0           [[726.0 g, lime juice], [732.0 g, lemon juice]]
# 1  [[1584.0 g, ice cream], [50.0 g, cream], [5.1 g, spice]]
#
#                                    ingredients_with_quantity  \
# 0  [[726.0 g, jus de citron vert], [732.0 g, jus de citron]]
# 1      [[1584.0 g, glace], [50.0 g, crème], [5.1 g, épices]]
#
#                              name_with_ingredients_en  \
# 0  " child's play" sour pops, lime juice, lemon juice
# 1       " fried egg sundaes", cream, ice cream, spice
#
#                                              name_with_ingredients
# 0  "Play de l'enfant" Sour Pops, jus de citron, jus de citron vert
# 1                 "Sundaes aux œufs au plat", épices, crème, glace

# %% [markdown]
# Keep only columns in french

# %%
seven_data_fr = seven_data[['ingredients_with_quantity', 'recipe_name', 'ingredients', 'name_with_ingredients']]
seven_data_fr.head(2)
# Out:
#                                    ingredients_with_quantity  \
# 0  [[726.0 g, jus de citron vert], [732.0 g, jus de citron]]
# 1      [[1584.0 g, glace], [50.0 g, crème], [5.1 g, épices]]
#
#                     recipe_name                          ingredients  \
# 0  "Play de l'enfant" Sour Pops  [jus de citron, jus de citron vert]
# 1    "Sundaes aux œufs au plat"               [épices, crème, glace]
#
#                                              name_with_ingredients
# 0  "Play de l'enfant" Sour Pops, jus de citron, jus de citron vert
# 1                 "Sundaes aux œufs au plat", épices, crème, glace

# %% [markdown]
# ## Concatenate the 2 databases

# %%
jow_data = jow_data[['ingredients_with_quantity', 'recipe_name', 'ingredients', 'name_with_ingredients']]

# %%
jow_data.head(2)
# Out:
#                                                                                                                ingredients_with_quantity  \
# Yakitori bœuf fromage         [[80 g, Bœuf (carpaccio)], [100 g, Emmental], [1 càs, Sauce Teriyaki], [70 g, Riz], [6, Pics à brochette]]
# Gnocchis Epinards Gorgonzola                     [[150 g, Gnocchi], [100 g, Epinard (frais)], [30 g, Gorgonzola], [5 cl, Crème liquide]]
#
#                                                recipe_name  \
# Yakitori bœuf fromage                Yakitori bœuf fromage
# Gnocchis Epinards Gorgonzola  Gnocchis Epinards Gorgonzola
#
#                                                                 ingredients  \
# Yakitori bœuf fromage                [Boeuf, Emmental, Sauce Teriyaki, Riz]
# Gnocchis Epinards Gorgonzola  [Gnocchi, Epinard, Gorgonzola, Crème liquide]
#
#                                                                                   name_with_ingredients
# Yakitori bœuf fromage                       Yakitori bœuf fromage, Boeuf, Emmental, Sauce Teriyaki, Riz
# Gnocchis Epinards Gorgonzola  Gnocchis Epinards Gorgonzola, Gnocchi, Epinard, Gorgonzola, Crème liquide

# %%
jow_7t_data = pd.concat([jow_data, seven_data_fr], axis = 0)

# %%
print("Number of recipes in jow_7t_data = ", jow_7t_data.shape[0])
# Out:
# Number of recipes in jow_7t_data =  8824

# %% [markdown]
# ## Pre-matching with NLP

# %%
! pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.8/dist-packages (2.2.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (1.13.1+cu116)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (1.7.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (4.64.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (0.12.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (1.0.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (4.26.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (0.14.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence_transformers) (3.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.25.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence_transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (4.0.0)

# %%
from sentence_transformers import SentenceTransformer, util
model =  SentenceTransformer("dangvantuan/sentence-camembert-large")
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/dangvantuan_sentence-camembert-large. Creating a new one with MEAN pooling.

# %% [markdown]
# We need first to compute the embedding of JOW+7t recipes labeled with 'name_with_ingredients'.

# %%
t0 = time.time()
jow7t_fullname_recipes = list(jow_7t_data['name_with_ingredients'].values)
jow7t_fullname_embeddings = model.encode(jow7t_fullname_recipes, convert_to_tensor=True)
print("Time lapse for JOW+7t embedding (s) = ", time.time()-t0)
# Out:
# Time lapse for JOW+7t embedding (s) =  50.469024658203125

# %% [markdown]
# For each menu recipe, we want to select with NLP all recipes in JOW+7t whose similary score s is larger than max_score - radius (for each menu recipe, max_score is the similarity score of the JOW+7t recipe that is the closest to the menu recipe).

# %%
# Function that returns the hits in data_base corresponding to the query,
# whose similarity scores are among the top_k biggest scores and larger than max_score - radius
def most_similar_recipes(query, database_embedding, model, top_k = 20, radius = 0.1):
    query_embedding = model.encode(query, convert_to_tensor=True)
    hits = util.semantic_search(query_embedding, database_embedding, top_k = top_k)    #find the top_k closest database recipes from query
    hits = hits[0]      #Get the hits for the first query (here only one query is given)

    # Keep only the recipes whose similarity scores are highest that max_score - radius
    best_hits = []
    for k, hit in enumerate(hits):
        max_score = hits[0]['score']  # hits is stored by descending scores
        if hit['score'] > max_score - radius:
            best_hits.append(hit)

    return best_hits


# Quick and dirty
# Function that finds for each recipe in the Series menu_data[menu_label_col] the closest matching recipes in the recipe database
# embedded in 'database_embedding' with the NLP model 'model'
# The function returns a dataframe with the results
def find_and_store_most_similar_recipes(menu_data, menu_label_col, database_embedding, model, top_k = 20, radius = 0.1):
    dict_res = {}

    for index, row in menu_data.iterrows():    # loop on rows of menu_data
        query = row[menu_label_col]
        
        best_hits = most_similar_recipes(query, database_embedding, model, top_k = top_k, radius = radius)
        
        # Store results in a dictionary
        for k, hit in enumerate(best_hits):
            jow7t_fullname_recipe = jow7t_fullname_recipes[hit['corpus_id']]
            jow7t_recipe = jow_7t_data[jow_7t_data['name_with_ingredients']==jow7t_fullname_recipe]['recipe_name'].values[0]
            
        
            # See if matching for this query had been found by hand
            closest_jow = row['Closest JOW recipe by hand']    # recipe in french
            closest_7t_en = row['Closest 7t recipe by hand']      # recipe in english

            # ... translate closest_7t_en in french
            if isinstance(closest_7t_en, list):
                # list of corresponding recipes in french
                closest_7t = [seven_data[seven_data['recipe_name_en']==recipe]['recipe_name'].values[0] for recipe in closest_7t_en]
            elif closest_7t_en!='no match':
                # corresponding recipe in french
                closest_7t = seven_data[seven_data['recipe_name_en']==closest_7t_en]['recipe_name'].values[0]  
            else:
                closest_7t = 'no match'

            # ... store in an index if the recipe guess corresponds to one of the matches found by hand
            if isinstance(closest_jow, list):
                matched_jow_idx = 1 if jow7t_recipe in closest_jow else 0
            else:
                matched_jow_idx = 1 if jow7t_recipe==closest_jow else 0

            if isinstance(closest_7t, list):
                matched_7t_idx = 1 if jow7t_recipe in closest_7t else 0
            else:
                matched_7t_idx = 1 if jow7t_recipe==closest_7t else 0

            matched_idx = max(matched_jow_idx, matched_7t_idx)

            # For each menu recipe (index) and hit (k), store 
            # menu_recipe_id, menu_recipe_label, jow7t_guess, similarity_rank, similary_score, is_matched_jow, is_matched_7t, is_matched_tot
            dict_res[str(index)+'_'+str(k)] = [query, jow7t_recipe, k+1, hit['score'], matched_jow_idx, matched_7t_idx, matched_idx]  

    # Convert the dictionary to a dataframe
    data_res = pd.DataFrame.from_dict(dict_res, orient = 'index', \
                                    columns = ['menu_recipe_label', 'jow7t_guess', 'similarity_rank', \
                                               'similarity_score', 'is_matched_jow', 'is_matched_7t', 'is_matched_tot'])\
                                    .reset_index(drop = True)

    return data_res

# %% [markdown]
# Run the NLP model by considering the full label of menu recipes (title+subtitle+ingredients if any) and the jow+7t recipes' names+ingredients (no quantity).
# **Remember this is run here only for menu recipes having at least one explicit match by hand with JOW or 7t.**

# %%
#top_k = jow7t_fullname_embeddings.shape[0]       # Number of JOW recipes
#df_res_step1 = find_and_store_most_similar_recipes(menu_data_withmatch, 'Menu all', jow7t_fullname_embeddings, model, top_k = top_k, radius = 0.05)
top_k = 5
df_res_step1 = find_and_store_most_similar_recipes(menu_data_withmatch, 'Menu all', jow7t_fullname_embeddings, model, top_k = top_k, radius = 1)
df_res_step1
# Out:
#                                                                                        menu_recipe_label  \
# 0    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 1    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 2    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 3    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 4    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# ..                                                                                                   ...
# 245           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 246           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 247           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 248           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 249           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
#
#                               jow7t_guess  similarity_rank  similarity_score  \
# 0                         Burger raclette                1          0.726083
# 1                           French Burger                2          0.721682
# 2                           Brunch Burger                3          0.706234
# 3                      Super Bacon Burger                4          0.696295
# 4                             Blue Burger                5          0.684877
# ..                                    ...              ...               ...
# 245             Saucisse purée & épinards                1          0.711127
# 246  purée de pommes de terre à la truffe                2          0.700466
# 247               Saucisse & purée maison                3          0.687571
# 248     Grilled cheese cochon à la truffe                4          0.680487
# 249                  Saucisse aux oignons                5          0.652563
#
#      is_matched_jow  is_matched_7t  is_matched_tot
# 0                 1              0               1
# 1                 1              0               1
# 2                 0              0               0
# 3                 1              0               1
# 4                 1              0               1
# ..              ...            ...             ...
# 245               1              0               1
# 246               0              0               0
# 247               1              0               1
# 248               0              0               0
# 249               0              0               0
#
# [250 rows x 7 columns]

# %% [markdown]
# Add the columns with matchings done by hand

# %%
df_res_step1['Closest JOW recipe by hand'] = df_res_step1['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest JOW recipe by hand'].values[0])
df_res_step1['Closest 7t recipe by hand'] = df_res_step1['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest 7t recipe by hand'].values[0])
df_res_step1
# Out:
#                                                                                        menu_recipe_label  \
# 0    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 1    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 2    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 3    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 4    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# ..                                                                                                   ...
# 245           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 246           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 247           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 248           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 249           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
#
#                               jow7t_guess  similarity_rank  similarity_score  \
# 0                         Burger raclette                1          0.726083
# 1                           French Burger                2          0.721682
# 2                           Brunch Burger                3          0.706234
# 3                      Super Bacon Burger                4          0.696295
# 4                             Blue Burger                5          0.684877
# ..                                    ...              ...               ...
# 245             Saucisse purée & épinards                1          0.711127
# 246  purée de pommes de terre à la truffe                2          0.700466
# 247               Saucisse & purée maison                3          0.687571
# 248     Grilled cheese cochon à la truffe                4          0.680487
# 249                  Saucisse aux oignons                5          0.652563
#
#      is_matched_jow  is_matched_7t  is_matched_tot  \
# 0                 1              0               1
# 1                 1              0               1
# 2                 0              0               0
# 3                 1              0               1
# 4                 1              0               1
# ..              ...            ...             ...
# 245               1              0               1
# 246               0              0               0
# 247               1              0               1
# 248               0              0               0
# 249               0              0               0
#
#                                                                                   Closest JOW recipe by hand  \
# 0        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 1        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 2        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 3        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 4        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# ..                                                                                                       ...
# 245  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 246  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 247  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 248  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 249  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
#
#                                                           Closest 7t recipe by hand
# 0                                                                          no match
# 1                                                                          no match
# 2                                                                          no match
# 3                                                                          no match
# 4                                                                          no match
# ..                                                                              ...
# 245  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 246  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 247  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 248  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 249  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
#
# [250 rows x 9 columns]

# %% [markdown]
# Let's have a closer look at menu recipes that have not been successfully matched

# %%
recipes_notmatched = df_res_step1[(df_res_step1['is_matched_tot']==0) & (df_res_step1['similarity_rank']==1)]['menu_recipe_label'].values.tolist()
print(len(recipes_notmatched))

df_res_step1[df_res_step1['menu_recipe_label'].isin(recipes_notmatched)]
# Out:
# 23
#                                                                                                     menu_recipe_label  \
# 10   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 11   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 12   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 13   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 14   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# ..                                                                                                                ...
# 235    Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 236    Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 237    Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 238    Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 239    Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
#
#                                  jow7t_guess  similarity_rank  \
# 10                            Italian burger                1
# 11                       Cheeseburger veggie                2
# 12                                Tom burger                3
# 13                      Classic Cheeseburger                4
# 14                             French Burger                5
# ..                                       ...              ...
# 235  Parmentier de canard aux patates douces                1
# 236                     Parmentier de canard                2
# 237                 Magret de canard & purée                3
# 238              Magret de canard à l'orange                4
# 239      Magret de canard & endives braisées                5
#
#      similarity_score  is_matched_jow  is_matched_7t  is_matched_tot  \
# 10           0.741322               0              0               0
# 11           0.718946               0              0               0
# 12           0.714138               0              0               0
# 13           0.707396               0              0               0
# 14           0.700665               0              0               0
# ..                ...             ...            ...             ...
# 235          0.675605               0              0               0
# 236          0.635657               1              0               1
# 237          0.634149               1              0               1
# 238          0.633614               0              0               0
# 239          0.626012               0              0               0
#
#                            Closest JOW recipe by hand  \
# 10                                           no match
# 11                                           no match
# 12                                           no match
# 13                                           no match
# 14                                           no match
# ..                                                ...
# 235  [Parmentier de canard, Magret de canard & purée]
# 236  [Parmentier de canard, Magret de canard & purée]
# 237  [Parmentier de canard, Magret de canard & purée]
# 238  [Parmentier de canard, Magret de canard & purée]
# 239  [Parmentier de canard, Magret de canard & purée]
#
#                                                                                                                 Closest 7t recipe by hand
# 10   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 11   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 12   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 13   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 14   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# ..                                                                                                                                    ...
# 235                                                                                                                              no match
# 236                                                                                                                              no match
# 237                                                                                                                              no match
# 238                                                                                                                              no match
# 239                                                                                                                              no match
#
# [115 rows x 9 columns]

# %%
print("Number of good matchings among outputs with rank 1 :")
df_res_step1[(df_res_step1['similarity_rank']==1) & (df_res_step1['is_matched_tot']==1)].shape[0]
# Out:
# Number of good matchings among outputs with rank 1 :
# 27

# %%
print("Number of good matchings among outputs with rank 1 which match JOW:")
df_res_step1[(df_res_step1['similarity_rank']==1) & (df_res_step1['is_matched_jow']==1)].shape[0]
# Out:
# Number of good matchings among outputs with rank 1 which match JOW:
# 24

# %%
print("Number of good matchings among outputs with rank 1 which match 7t:")
df_res_step1[(df_res_step1['similarity_rank']==1) & (df_res_step1['is_matched_7t']==1)].shape[0]
# Out:
# Number of good matchings among outputs with rank 1 which match 7t:
# 3

# %%
df_tmp = pd.DataFrame(df_res_step1.groupby('menu_recipe_label')['is_matched_tot'].agg(sum))
df_tmp['is_matched_tot'] = df_tmp['is_matched_tot'].apply(lambda x: x if x==0 else 1)

print("Number of good matchings among the cloud of pre-selected recipes :")
df_tmp[df_tmp['is_matched_tot']==1].shape[0]
# Out:
# Number of good matchings among the cloud of pre-selected recipes :
# 37

# %% [markdown]
# There are some menu recipes for which we had a match when using the NLP model for the database 7t only while the match is lost when the full database (jow+7t) is used, eg:
# - Classiques, Bulgogi, Bœuf émincé à la sauce soja, légumes, riz
#
# There are some menu recipes for which we had a match when using the NLP model for the database JOW only while the match is lost when the full database (jow+7t) is used, eg:
# - Desserts, Mousse au chocolat maison
#
# There are also some menu recipes for which we had no match when using the NLP model for the database JOW only while we have a match when the full database (jow+7t) is used, eg:
# - Sides, Frites, (v)

# %%
fig = sns.catplot(data = df_res_step1, x = 'menu_recipe_label', y = 'similarity_score',  \
                  hue = 'is_matched_tot', kind = 'swarm', aspect = 5)
fig.set_xticklabels(rotation=90);

# %% [markdown]
# Let's have a look at predictions for recipes which could not be matched by hand

# %%
menu_data_nomatch = menu_data[(menu_data['Closest 7t recipe by hand']=='no match') & (menu_data['Closest JOW recipe by hand']=='no match')]
print("Number of queries = ", menu_data_nomatch.shape[0])
# Out:
# Number of queries =  10

# %%
#top_k = jow7t_fullname_embeddings.shape[0]       # Number of JOW recipes
#df_res_step1 = find_and_store_most_similar_recipes(menu_data_nomatch, 'Menu all', jow7t_fullname_embeddings, model, top_k = top_k, radius = 0.05)
top_k = 5
df_res_step2 = find_and_store_most_similar_recipes(menu_data_nomatch, 'Menu all', jow7t_fullname_embeddings, model, top_k = top_k, radius = 1)

#Add the columns with matchings done by hand
df_res_step2['Closest JOW recipe by hand'] = df_res_step2['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest JOW recipe by hand'].values[0])
df_res_step2['Closest 7t recipe by hand'] = df_res_step2['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest 7t recipe by hand'].values[0])
df_res_step2
# Out:
#                                                                                         menu_recipe_label  \
# 0                                        Anju, Mandoo (6 pcs), Raviolis maison grillés au porc et légumes
# 1                                        Anju, Mandoo (6 pcs), Raviolis maison grillés au porc et légumes
# 2                                        Anju, Mandoo (6 pcs), Raviolis maison grillés au porc et légumes
# 3                                        Anju, Mandoo (6 pcs), Raviolis maison grillés au porc et légumes
# 4                                        Anju, Mandoo (6 pcs), Raviolis maison grillés au porc et légumes
# 5                                                                 Anju, Haemul Jeol, Galette de fruit mer
# 6                                                                 Anju, Haemul Jeol, Galette de fruit mer
# 7                                                                 Anju, Haemul Jeol, Galette de fruit mer
# 8                                                                 Anju, Haemul Jeol, Galette de fruit mer
# 9                                                                 Anju, Haemul Jeol, Galette de fruit mer
# 10                                                 Bibimbap, Dolsot bibimbap (en pierrade au choix), Bœuf
# 11                                                 Bibimbap, Dolsot bibimbap (en pierrade au choix), Bœuf
# 12                                                 Bibimbap, Dolsot bibimbap (en pierrade au choix), Bœuf
# 13                                                 Bibimbap, Dolsot bibimbap (en pierrade au choix), Bœuf
# 14                                                 Bibimbap, Dolsot bibimbap (en pierrade au choix), Bœuf
# 15                                  Classiques, Ojing-oe, Calamar sauté, légumes, riz - soja ou piquant )
# 16                                  Classiques, Ojing-oe, Calamar sauté, légumes, riz - soja ou piquant )
# 17                                  Classiques, Ojing-oe, Calamar sauté, légumes, riz - soja ou piquant )
# 18                                  Classiques, Ojing-oe, Calamar sauté, légumes, riz - soja ou piquant )
# 19                                  Classiques, Ojing-oe, Calamar sauté, légumes, riz - soja ou piquant )
# 20                                                      Végé pour tous, Moussaka végétarienne, aux gombos
# 21                                                      Végé pour tous, Moussaka végétarienne, aux gombos
# 22                                                      Végé pour tous, Moussaka végétarienne, aux gombos
# 23                                                      Végé pour tous, Moussaka végétarienne, aux gombos
# 24                                                      Végé pour tous, Moussaka végétarienne, aux gombos
# 25                    Starters, Carpaccio Thon Sésame, Tuna carpaccio, miso, mango and lime salsa, chilli
# 26                    Starters, Carpaccio Thon Sésame, Tuna carpaccio, miso, mango and lime salsa, chilli
# 27                    Starters, Carpaccio Thon Sésame, Tuna carpaccio, miso, mango and lime salsa, chilli
# 28                    Starters, Carpaccio Thon Sésame, Tuna carpaccio, miso, mango and lime salsa, chilli
# 29                    Starters, Carpaccio Thon Sésame, Tuna carpaccio, miso, mango and lime salsa, chilli
# 30               Calzoni, Calzone parigino, mozzarella, jambon, champignons, œuf, sauce tomates au dessus
# 31               Calzoni, Calzone parigino, mozzarella, jambon, champignons, œuf, sauce tomates au dessus
# 32               Calzoni, Calzone parigino, mozzarella, jambon, champignons, œuf, sauce tomates au dessus
# 33               Calzoni, Calzone parigino, mozzarella, jambon, champignons, œuf, sauce tomates au dessus
# 34               Calzoni, Calzone parigino, mozzarella, jambon, champignons, œuf, sauce tomates au dessus
# 35                                                                Pasta, Penne Arrabiatta, Tomate, piment
# 36                                                                Pasta, Penne Arrabiatta, Tomate, piment
# 37                                                                Pasta, Penne Arrabiatta, Tomate, piment
# 38                                                                Pasta, Penne Arrabiatta, Tomate, piment
# 39                                                                Pasta, Penne Arrabiatta, Tomate, piment
# 40                                                                                  Dessert, Baba au Rhum
# 41                                                                                  Dessert, Baba au Rhum
# 42                                                                                  Dessert, Baba au Rhum
# 43                                                                                  Dessert, Baba au Rhum
# 44                                                                                  Dessert, Baba au Rhum
# 45  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 46  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 47  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 48  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 49  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
#
#                                            jow7t_guess  similarity_rank  \
# 0               Recette de filet de porc grillé grillé                1
# 1           brochettes de porc grillées avec gingembre                2
# 2   Salade de porc et de nouilles de style thaïlandais                3
# 3          recette chinoise de porc grillé (ch'a hsao)                4
# 4                         Nouilles de riz & porc sauté                5
# 5                                     Galette complète                1
# 6                                Eggs & salmon muffins                2
# 7                 Poisson pané, purée & haricots verts                3
# 8                           Tilapia en croûte de pacan                4
# 9                                       Galette Seguin                5
# 10               Brochettes de bœuf, blé & ratatouille                1
# 11            Bavette à l'échalote & purée de brocolis                2
# 12                     recette de bœuf bœuf scaloppini                3
# 13                                 Wrap au bœuf braisé                4
# 14                                Rôti de bœuf & purée                5
# 15                   Légumes sautés, gingembre & cajou                1
# 16                             Riz sauté aux crevettes                2
# 17                          Riz sauté & sauce pimentée                3
# 18                                           riz sauté                4
# 19                   Cabillaud & riz sauté aux légumes                5
# 20                                     frites de gombo                1
# 21                                 Tikka Masala veggie                2
# 22                                     Couscous veggie                3
# 23                       Roasted veggies & hummus bowl                4
# 24                      Nuggets veggie, riz & brocolis                5
# 25                                  Fish & mango tacos                1
# 26                              Sauce tartare du cumin                2
# 27                                      Pasta al tonno                3
# 28              Papillote saumon pesto & légumes d'été                4
# 29                      Salade de riz thon & coriandre                5
# 30                              Italian grilled cheese                1
# 31                                   Pizza printanière                2
# 32                                    Bruschetta parma                3
# 33                                         Pizza Parma                4
# 34                     Enchiladas poulet & champignons                5
# 35                                    Pasta alla Norma                1
# 36                                        Pasta & ragu                2
# 37                           Spaghetti alla puttanesca                3
# 38                       Pasta verde & tomates cerises                4
# 39                       Salade de pâtes, pesto, mozza                5
# 40                         Dessert spécial aux fraises                1
# 41                      Fabuleuse trempette aux fruits                2
# 42                                    Crème sure sucre                3
# 43               trempette aux fruits de la crème sure                4
# 44            pâte de whisky (ou rhum) au beurre chaud                5
# 45                                          Tom burger                1
# 46                                       French Burger                2
# 47                                         Blue Burger                3
# 48             Grilled cheese poulet & confit d'oignon                4
# 49                                Classic Cheeseburger                5
#
#     similarity_score  is_matched_jow  is_matched_7t  is_matched_tot  \
# 0           0.640620               0              0               0
# 1           0.634679               0              0               0
# 2           0.628194               0              0               0
# 3           0.625431               0              0               0
# 4           0.619716               0              0               0
# 5           0.449843               0              0               0
# 6           0.438509               0              0               0
# 7           0.429313               0              0               0
# 8           0.426207               0              0               0
# 9           0.425963               0              0               0
# 10          0.643055               0              0               0
# 11          0.617408               0              0               0
# 12          0.609414               0              0               0
# 13          0.587017               0              0               0
# 14          0.568940               0              0               0
# 15          0.676044               0              0               0
# 16          0.669668               0              0               0
# 17          0.652474               0              0               0
# 18          0.648210               0              0               0
# 19          0.639570               0              0               0
# 20          0.627808               0              0               0
# 21          0.535201               0              0               0
# 22          0.533713               0              0               0
# 23          0.525265               0              0               0
# 24          0.525054               0              0               0
# 25          0.588506               0              0               0
# 26          0.585102               0              0               0
# 27          0.580435               0              0               0
# 28          0.576344               0              0               0
# 29          0.569826               0              0               0
# 30          0.697187               0              0               0
# 31          0.692862               0              0               0
# 32          0.690324               0              0               0
# 33          0.688282               0              0               0
# 34          0.682079               0              0               0
# 35          0.808296               0              0               0
# 36          0.759603               0              0               0
# 37          0.756683               0              0               0
# 38          0.752889               0              0               0
# 39          0.742613               0              0               0
# 40          0.588435               0              0               0
# 41          0.582432               0              0               0
# 42          0.572916               0              0               0
# 43          0.564706               0              0               0
# 44          0.561749               0              0               0
# 45          0.692306               0              0               0
# 46          0.689379               0              0               0
# 47          0.686737               0              0               0
# 48          0.662828               0              0               0
# 49          0.656692               0              0               0
#
#    Closest JOW recipe by hand Closest 7t recipe by hand
# 0                    no match                  no match
# 1                    no match                  no match
# 2                    no match                  no match
# 3                    no match                  no match
# 4                    no match                  no match
# 5                    no match                  no match
# 6                    no match                  no match
# 7                    no match                  no match
# 8                    no match                  no match
# 9                    no match                  no match
# 10                   no match                  no match
# 11                   no match                  no match
# 12                   no match                  no match
# 13                   no match                  no match
# 14                   no match                  no match
# 15                   no match                  no match
# 16                   no match                  no match
# 17                   no match                  no match
# 18                   no match                  no match
# 19                   no match                  no match
# 20                   no match                  no match
# 21                   no match                  no match
# 22                   no match                  no match
# 23                   no match                  no match
# 24                   no match                  no match
# 25                   no match                  no match
# 26                   no match                  no match
# 27                   no match                  no match
# 28                   no match                  no match
# 29                   no match                  no match
# 30                   no match                  no match
# 31                   no match                  no match
# 32                   no match                  no match
# 33                   no match                  no match
# 34                   no match                  no match
# 35                   no match                  no match
# 36                   no match                  no match
# 37                   no match                  no match
# 38                   no match                  no match
# 39                   no match                  no match
# 40                   no match                  no match
# 41                   no match                  no match
# 42                   no match                  no match
# 43                   no match                  no match
# 44                   no match                  no match
# 45                   no match                  no match
# 46                   no match                  no match
# 47                   no match                  no match
# 48                   no match                  no match
# 49                   no match                  no match

# %% [markdown]
# ## Repeat the NLP task by considering only the JOW database

# %% [markdown]
# Compute the embedding of JOW recipes labeled with 'name_with_ingredients'.

# %%
t0 = time.time()
jow_fullname_recipes = list(jow_data['name_with_ingredients'].values)
jow_fullname_embeddings = model.encode(jow_fullname_recipes, convert_to_tensor=True)
print("Time lapse for JOW embedding (s) = ", time.time()-t0)
# Out:
# Time lapse for JOW embedding (s) =  9.306087493896484

# %% [markdown]
# For each menu recipe, we want to select with NLP all recipes in JOW whose similary score s is larger than max_score - radius (for each menu recipe, max_score is the similarity score of the JOW recipe that is the closest to the menu recipe).

# %%
# Quick and dirty
# Function that finds for each recipe in the Series menu_data[menu_label_col] the closest matching recipes in the recipe database
# embedded in 'database_embedding' with the NLP model 'model'
# The function returns a dataframe with the results
def find_and_store_most_similar_recipes(menu_data, menu_label_col, database_embedding, model, top_k = 20, radius = 0.1):
    dict_res = {}

    for index, row in menu_data.iterrows():    # loop on rows of menu_data
        query = row[menu_label_col]
        
        best_hits = most_similar_recipes(query, database_embedding, model, top_k = top_k, radius = radius)
        
        # Store results in a dictionary
        for k, hit in enumerate(best_hits):
            jow_fullname_recipe = jow_fullname_recipes[hit['corpus_id']]
            jow_recipe = jow_data[jow_data['name_with_ingredients']==jow_fullname_recipe].index[0]
        
            # See if matching for this query had been found by hand
            closest_jow = row['Closest JOW recipe by hand']    # recipe in french

            # ... store in an index if the recipe guess corresponds to one of the matches found by hand
            if isinstance(closest_jow, list):
                matched_jow_idx = 1 if jow_recipe in closest_jow else 0
            else:
                matched_jow_idx = 1 if jow_recipe==closest_jow else 0


            # For each menu recipe (index) and hit (k), store 
            # menu_recipe_id, menu_recipe_label, jow7t_guess, similarity_rank, similary_score, is_matched_jow, is_matched_7t, is_matched_tot
            dict_res[str(index)+'_'+str(k)] = [query, jow_recipe, k+1, hit['score'], matched_jow_idx]  

    # Convert the dictionary to a dataframe
    data_res = pd.DataFrame.from_dict(dict_res, orient = 'index', \
                                    columns = ['menu_recipe_label', 'jow_guess', 'similarity_rank', \
                                               'similarity_score', 'is_matched_jow'])\
                                    .reset_index(drop = True)

    return data_res

# %% [markdown]
# Let's first look at predictions for recipes which could be matched by hand

# %%
menu_data_withmatchjow = menu_data[menu_data['Closest JOW recipe by hand']!='no match']
print("Number of queries = ", menu_data_withmatchjow.shape[0])
# Out:
# Number of queries =  44

# %%
#top_k = jow7t_fullname_embeddings.shape[0]       # Number of JOW recipes
#df_res_step3 = find_and_store_most_similar_recipes(menu_data_withmatchjow, 'Menu all', jow_fullname_embeddings, model, top_k = top_k, radius = 0.05)
top_k = 5
df_res_step3 = find_and_store_most_similar_recipes(menu_data_withmatchjow, 'Menu all', jow_fullname_embeddings, model, top_k = top_k, radius = 1)

#Add the columns with matchings done by hand
df_res_step3['Closest JOW recipe by hand'] = df_res_step3['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest JOW recipe by hand'].values[0])
df_res_step3['Closest 7t recipe by hand'] = df_res_step3['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest 7t recipe by hand'].values[0])
df_res_step3
# Out:
#                                                                                        menu_recipe_label  \
# 0    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 1    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 2    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 3    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 4    Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# ..                                                                                                   ...
# 215           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 216           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 217           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 218           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 219           Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
#
#                              jow_guess  similarity_rank  similarity_score  \
# 0                      Burger raclette                1          0.726083
# 1                        French Burger                2          0.721682
# 2                        Brunch Burger                3          0.706234
# 3                   Super Bacon Burger                4          0.696295
# 4                          Blue Burger                5          0.684877
# ..                                 ...              ...               ...
# 215          Saucisse purée & épinards                1          0.711127
# 216            Saucisse & purée maison                2          0.687571
# 217  Grilled cheese cochon à la truffe                3          0.680487
# 218               Saucisse aux oignons                4          0.652563
# 219     Saucisse & purée de potimarron                5          0.651355
#
#      is_matched_jow  \
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 1
# ..              ...
# 215               1
# 216               1
# 217               0
# 218               0
# 219               0
#
#                                                                                   Closest JOW recipe by hand  \
# 0        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 1        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 2        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 3        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 4        [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# ..                                                                                                       ...
# 215  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 216  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 217  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 218  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 219  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
#
#                                                           Closest 7t recipe by hand
# 0                                                                          no match
# 1                                                                          no match
# 2                                                                          no match
# 3                                                                          no match
# 4                                                                          no match
# ..                                                                              ...
# 215  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 216  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 217  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 218  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 219  [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
#
# [220 rows x 7 columns]

# %%
print("Number of good matchings among outputs with rank 1 :")
df_res_step3[(df_res_step3['similarity_rank']==1) & (df_res_step3['is_matched_jow']==1)].shape[0]
# Out:
# Number of good matchings among outputs with rank 1 :
# 28

# %%
df_tmp = pd.DataFrame(df_res_step3.groupby('menu_recipe_label')['is_matched_jow'].agg(sum))
df_tmp['is_matched_jow'] = df_tmp['is_matched_jow'].apply(lambda x: x if x==0 else 1)

print("Number of good matchings among the cloud of pre-selected recipes :")
df_tmp[df_tmp['is_matched_jow']==1].shape[0]
# Out:
# Number of good matchings among the cloud of pre-selected recipes :
# 37

# %% [markdown]
# Let's have a closer look at menu recipes that have not been successfully matched

# %%
recipes_notmatched2 = df_res_step3[(df_res_step3['is_matched_jow']==0) & (df_res_step3['similarity_rank']==1)]['menu_recipe_label'].values.tolist()
print(len(recipes_notmatched2))

df_res_step3[df_res_step3['menu_recipe_label'].isin(recipes_notmatched2)]
# Out:
# 16
#                                                                                                   menu_recipe_label  \
# 40                                       Anju, Sewoo kkanpoong (8 pcs), Crevettes frites dans une sauce aigre douce
# 41                                       Anju, Sewoo kkanpoong (8 pcs), Crevettes frites dans une sauce aigre douce
# 42                                       Anju, Sewoo kkanpoong (8 pcs), Crevettes frites dans une sauce aigre douce
# 43                                       Anju, Sewoo kkanpoong (8 pcs), Crevettes frites dans une sauce aigre douce
# 44                                       Anju, Sewoo kkanpoong (8 pcs), Crevettes frites dans une sauce aigre douce
# ..                                                                                                              ...
# 205  Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 206  Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 207  Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 208  Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
# 209  Les plats, Canard, purée de cresson, pommes boulangères, trompettes de la mort & jus de volaille à l'argousier
#
#                                    jow_guess  similarity_rank  \
# 40        Poêlée crevettes & légumes express                1
# 41            Nouilles sautées aux crevettes                2
# 42                         Pad Thaï crevette                3
# 43              Nouilles de riz & porc sauté                4
# 44                   Riz sauté aux crevettes                5
# ..                                       ...              ...
# 205  Parmentier de canard aux patates douces                1
# 206                     Parmentier de canard                2
# 207                 Magret de canard & purée                3
# 208              Magret de canard à l'orange                4
# 209      Magret de canard & endives braisées                5
#
#      similarity_score  is_matched_jow  \
# 40           0.621381               0
# 41           0.600914               0
# 42           0.594309               0
# 43           0.571034               0
# 44           0.565556               0
# ..                ...             ...
# 205          0.675605               0
# 206          0.635657               1
# 207          0.634149               1
# 208          0.633614               0
# 209          0.626012               0
#
#                            Closest JOW recipe by hand  \
# 40        [Crevettes teriyaki, Crevettes miel sésame]
# 41        [Crevettes teriyaki, Crevettes miel sésame]
# 42        [Crevettes teriyaki, Crevettes miel sésame]
# 43        [Crevettes teriyaki, Crevettes miel sésame]
# 44        [Crevettes teriyaki, Crevettes miel sésame]
# ..                                                ...
# 205  [Parmentier de canard, Magret de canard & purée]
# 206  [Parmentier de canard, Magret de canard & purée]
# 207  [Parmentier de canard, Magret de canard & purée]
# 208  [Parmentier de canard, Magret de canard & purée]
# 209  [Parmentier de canard, Magret de canard & purée]
#
#     Closest 7t recipe by hand
# 40                   no match
# 41                   no match
# 42                   no match
# 43                   no match
# 44                   no match
# ..                        ...
# 205                  no match
# 206                  no match
# 207                  no match
# 208                  no match
# 209                  no match
#
# [80 rows x 7 columns]

# %% [markdown]
# Let's have a look at predictions for recipes which could not be matched by hand

# %%
menu_data_nomatchjow = menu_data[menu_data['Closest JOW recipe by hand']=='no match']
print("Number of queries = ", menu_data_nomatchjow.shape[0])
# Out:
# Number of queries =  16

# %%
#top_k = jow7t_fullname_embeddings.shape[0]       # Number of JOW recipes
#df_res_step4 = find_and_store_most_similar_recipes(menu_data_nomatchjow, 'Menu all', jow_fullname_embeddings, model, top_k = top_k, radius = 0.05)
top_k = 5
df_res_step4 = find_and_store_most_similar_recipes(menu_data_nomatchjow, 'Menu all', jow_fullname_embeddings, model, top_k = top_k, radius = 1)

#Add the columns with matchings done by hand
df_res_step4['Closest JOW recipe by hand'] = df_res_step4['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest JOW recipe by hand'].values[0])
df_res_step4['Closest 7t recipe by hand'] = df_res_step4['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest 7t recipe by hand'].values[0])
df_res_step4
# Out:
#                                                                                                    menu_recipe_label  \
# 0   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 1   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 2   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 3   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 4   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# ..                                                                                                               ...
# 75             Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 76             Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 77             Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 78             Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 79             Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
#
#                                   jow_guess  similarity_rank  \
# 0                            Italian burger                1
# 1                       Cheeseburger veggie                2
# 2                                Tom burger                3
# 3                      Classic Cheeseburger                4
# 4                             French Burger                5
# ..                                      ...              ...
# 75                               Tom burger                1
# 76                            French Burger                2
# 77                              Blue Burger                3
# 78  Grilled cheese poulet & confit d'oignon                4
# 79                     Classic Cheeseburger                5
#
#     similarity_score  is_matched_jow Closest JOW recipe by hand  \
# 0           0.741322               0                   no match
# 1           0.718946               0                   no match
# 2           0.714138               0                   no match
# 3           0.707396               0                   no match
# 4           0.700665               0                   no match
# ..               ...             ...                        ...
# 75          0.692306               0                   no match
# 76          0.689379               0                   no match
# 77          0.686737               0                   no match
# 78          0.662828               0                   no match
# 79          0.656692               0                   no match
#
#                                                                                                                Closest 7t recipe by hand
# 0   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 1   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 2   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 3   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 4   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# ..                                                                                                                                   ...
# 75                                                                                                                              no match
# 76                                                                                                                              no match
# 77                                                                                                                              no match
# 78                                                                                                                              no match
# 79                                                                                                                              no match
#
# [80 rows x 7 columns]

# %% [markdown]
# ## Repeat the NLP task by considering only the 7t database

# %% [markdown]
# Compute the embedding of 7t recipes labeled with 'name_with_ingredients'.

# %%
t0 = time.time()
seven_fullname_recipes = list(seven_data['name_with_ingredients'].values)
seven_fullname_embeddings = model.encode(seven_fullname_recipes, convert_to_tensor=True)
print("Time lapse for 7t embedding (s) = ", time.time()-t0)
# Out:
# Time lapse for 7t embedding (s) =  35.04241871833801

# %% [markdown]
# For each menu recipe, we want to select with NLP all recipes in 7t whose similary score s is larger than max_score - radius (for each menu recipe, max_score is the similarity score of the 7t recipe that is the closest to the menu recipe).

# %%
# Quick and dirty
# Function that finds for each recipe in the Series menu_data[menu_label_col] the closest matching recipes in the recipe database
# embedded in 'database_embedding' with the NLP model 'model'
# The function returns a dataframe with the results
def find_and_store_most_similar_recipes(menu_data, menu_label_col, database_embedding, model, top_k = 20, radius = 0.1):
    dict_res = {}

    for index, row in menu_data.iterrows():    # loop on rows of menu_data
        query = row[menu_label_col]
        
        best_hits = most_similar_recipes(query, database_embedding, model, top_k = top_k, radius = radius)
        
        # Store results in a dictionary
        for k, hit in enumerate(best_hits):
            seven_fullname_recipe = seven_fullname_recipes[hit['corpus_id']]
            seven_recipe = seven_data[seven_data['name_with_ingredients']==seven_fullname_recipe]['recipe_name'].values[0]   # in french
            seven_recipe_en = seven_data[seven_data['recipe_name']==seven_recipe]['recipe_name_en'].values[0]  # in english
            
        
            # See if matching for this query had been found by hand
            closest_7t_en = row['Closest 7t recipe by hand']      # recipe in english

            # ... translate closest_7t_en in french
            if isinstance(closest_7t_en, list):
                # list of corresponding recipes in french
                closest_7t = [seven_data[seven_data['recipe_name_en']==recipe]['recipe_name'].values[0] for recipe in closest_7t_en]
            elif closest_7t_en!='no match':
                # corresponding recipe in french
                closest_7t = seven_data[seven_data['recipe_name_en']==closest_7t_en]['recipe_name'].values[0]  
            else:
                closest_7t = 'no match'

            # ... store in an index if the recipe guess corresponds to one of the matches found by hand
            if isinstance(closest_7t, list):
                matched_7t_idx = 1 if seven_recipe in closest_7t else 0
            else:
                matched_7t_idx = 1 if seven_recipe==closest_7t else 0


            # For each menu recipe (index) and hit (k), store 
            # menu_recipe_id, menu_recipe_label, jow7t_guess, similarity_rank, similary_score, is_matched_jow, is_matched_7t, is_matched_tot
            dict_res[str(index)+'_'+str(k)] = [query, seven_recipe_en, k+1, hit['score'], matched_7t_idx]  

    # Convert the dictionary to a dataframe
    data_res = pd.DataFrame.from_dict(dict_res, orient = 'index', \
                                    columns = ['menu_recipe_label', '7t_guess', 'similarity_rank', \
                                               'similarity_score', 'is_matched_7t'])\
                                    .reset_index(drop = True)

    return data_res

# %% [markdown]
# Let's first look at predictions for recipes which could be matched by hand

# %%
menu_data_withmatch7t = menu_data[menu_data['Closest 7t recipe by hand']!='no match']
print("Number of queries = ", menu_data_withmatch7t.shape[0])
# Out:
# Number of queries =  19

# %%
#top_k = jow7t_fullname_embeddings.shape[0]       # Number of JOW recipes
#df_res_step5 = find_and_store_most_similar_recipes(menu_data_withmatch7t, 'Menu all', jow_fullname_embeddings, model, top_k = top_k, radius = 0.05)
top_k = 5
df_res_step5 = find_and_store_most_similar_recipes(menu_data_withmatch7t, 'Menu all', seven_fullname_embeddings, model, top_k = top_k, radius = 1)

#Add the columns with matchings done by hand
df_res_step5['Closest JOW recipe by hand'] = df_res_step5['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest JOW recipe by hand'].values[0])
df_res_step5['Closest 7t recipe by hand'] = df_res_step5['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest 7t recipe by hand'].values[0])
df_res_step5
# Out:
#                                                                                                    menu_recipe_label  \
# 0   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 1   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 2   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 3   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# 4   Burgers, Green Chicken, Filet de poulet, Tomme de Savoie IGP, Roquette, Mortadelle, Parmesan, Sauce verte maison
# ..                                                                                                               ...
# 90                        Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 91                        Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 92                        Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 93                        Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
# 94                        Plats, Saucisse - Purée truffée, Saucisse d'Auvergne, purée à la truffe, crème d'Abondance
#
#                                                                          7t_guess  \
# 0                                                    poulet et brocoli hamburgers
# 1                                                  Burgers de dinde feta épinards
# 2                                       hamburgers de dinde farci au fromage bleu
# 3                                                         Franks Chicken Wing Dip
# 4                                Salade de césar de poulet grillé mieux pour vous
# ..                                                                            ...
# 90                                           purée de pommes de terre à la truffe
# 91                                                   Chips de truffe frit au four
# 92  purée de pommes de terre au four avec de la crème sure et de la recette d'ail
# 93                                                boules de fromage à la saucisse
# 94        Crème sure au fromage et camionnette de purée de pommes de terre dorées
#
#     similarity_rank  similarity_score  is_matched_7t  \
# 0                 1          0.674721              1
# 1                 2          0.645711              1
# 2                 3          0.642835              1
# 3                 4          0.635661              0
# 4                 5          0.627000              0
# ..              ...               ...            ...
# 90                1          0.700466              0
# 91                2          0.627701              0
# 92                3          0.612049              0
# 93                4          0.604986              0
# 94                5          0.591889              0
#
#                                                                                  Closest JOW recipe by hand  \
# 0                                                                                                  no match
# 1                                                                                                  no match
# 2                                                                                                  no match
# 3                                                                                                  no match
# 4                                                                                                  no match
# ..                                                                                                      ...
# 90  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 91  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 92  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 93  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
# 94  [Saucisse & purée maison, Saucisse purée & épinards, Pommes de terre & saucisses rôties, Knack & purée]
#
#                                                                                                                Closest 7t recipe by hand
# 0   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 1   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 2   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 3   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# 4   [awesome turkey burgers, blue cheese stuffed turkey burgers, chicken & broccoli burgers, greek burgers, spinach feta turkey burgers]
# ..                                                                                                                                   ...
# 90                                                        [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 91                                                        [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 92                                                        [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 93                                                        [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
# 94                                                        [sweet potatoes with pecans & sausage, sweet potatoes with pecans and sausage]
#
# [95 rows x 7 columns]

# %%
print("Number of good matchings among outputs with rank 1 :")
df_res_step5[(df_res_step5['similarity_rank']==1) & (df_res_step5['is_matched_7t']==1)].shape[0]
# Out:
# Number of good matchings among outputs with rank 1 :
# 8

# %%
df_tmp = pd.DataFrame(df_res_step5.groupby('menu_recipe_label')['is_matched_7t'].agg(sum))
df_tmp['is_matched_7t'] = df_tmp['is_matched_7t'].apply(lambda x: x if x==0 else 1)

print("Number of good matchings among the cloud of pre-selected recipes :")
df_tmp[df_tmp['is_matched_7t']==1].shape[0]
# Out:
# Number of good matchings among the cloud of pre-selected recipes :
# 9

# %% [markdown]
# Let's have a look at predictions for recipes which could not be matched by hand

# %%
menu_data_nomatch7t = menu_data[menu_data['Closest 7t recipe by hand']=='no match']
print("Number of queries = ", menu_data_nomatch7t.shape[0])
# Out:
# Number of queries =  41

# %%
#top_k = jow7t_fullname_embeddings.shape[0]       # Number of JOW recipes
#df_res_step6 = find_and_store_most_similar_recipes(menu_data_nomatch7t, 'Menu all', seven_fullname_embeddings, model, top_k = top_k, radius = 0.05)
top_k = 5
df_res_step6 = find_and_store_most_similar_recipes(menu_data_nomatch7t, 'Menu all', seven_fullname_embeddings, model, top_k = top_k, radius = 1)

#Add the columns with matchings done by hand
df_res_step6['Closest JOW recipe by hand'] = df_res_step6['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest JOW recipe by hand'].values[0])
df_res_step6['Closest 7t recipe by hand'] = df_res_step6['menu_recipe_label'].apply(lambda recipe: menu_data[menu_data['Menu all']==recipe]['Closest 7t recipe by hand'].values[0])
df_res_step6
# Out:
#                                                                                          menu_recipe_label  \
# 0      Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 1      Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 2      Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 3      Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# 4      Burgers, Superfin, Bœuf (VBF Metzger), Comté AOC, Iceberg, Bacon, Compotée d'oignons, Sauce Burgart
# ..                                                                                                     ...
# 200  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 201  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 202  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 203  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
# 204  Plats, Hot-Duck, Pain brioché, confit de canard, ketchup de pomme, coleslaw, Tomme des Aravis, frites
#
#                                                    7t_guess  similarity_rank  \
# 0                                   blue cheese steak sauce                1
# 1                            blue cheese steak sauce recipe                2
# 2                                             greek burgers                3
# 3                            barbecue burger topping recipe                4
# 4                                    awesome turkey burgers                5
# ..                                                      ...              ...
# 200                      blue cheese stuffed turkey burgers                1
# 201                                oven-fried truffle chips                2
# 202  copycat wings and things chicken tenders and hot sauce                3
# 203                                 franks chicken wing dip                4
# 204             goat cheese potato cakes with smoked salmon                5
#
#      similarity_score  is_matched_7t  \
# 0            0.629188              0
# 1            0.626171              0
# 2            0.621317              0
# 3            0.611194              0
# 4            0.610796              0
# ..                ...            ...
# 200          0.645685              0
# 201          0.629768              0
# 202          0.619986              0
# 203          0.615403              0
# 204          0.607585              0
#
#                                                                               Closest JOW recipe by hand  \
# 0    [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 1    [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 2    [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 3    [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# 4    [Blue Burger, French Burger, Classic Cheeseburger, Super Bacon Burger, Tom burger, Burger raclette]
# ..                                                                                                   ...
# 200                                                                                             no match
# 201                                                                                             no match
# 202                                                                                             no match
# 203                                                                                             no match
# 204                                                                                             no match
#
#     Closest 7t recipe by hand
# 0                    no match
# 1                    no match
# 2                    no match
# 3                    no match
# 4                    no match
# ..                        ...
# 200                  no match
# 201                  no match
# 202                  no match
# 203                  no match
# 204                  no match
#
# [205 rows x 7 columns]
