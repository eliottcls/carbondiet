# %%
import cv2
from project.ComputerVision.ocr import OCR

# %% [markdown]
# Input absolute path toward image as input.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Import image

# %%
img = 'C:/Users/EliottCOLSON/OneDrive - Ekimetrics/Documents/carbondiet/data/images/menu1.png' # copy absolute path toward image
image = cv2.imread(img)

# %% [markdown]
# #### Set-up model

# %%
ocr = OCR()

# %%
dict_results = ocr.extract_text_from_menu(image)

# %% [markdown]
# #### Diplay results

# %%
print(dict_results)

# %% [markdown]
# #### [Optional] Display image and boxes

# %%
from project.ComputerVision.box_detection import BoundingBoxDetection

# %%
boxdetect = BoundingBoxDetection()

# %%
cv2.imshow("image", boxdetect.display_boxes(image))
cv2.waitKey(0)
# Out:
# 0: 800x608 24 Recipes, 2 Section titles, 873.4ms
# Speed: 2.5ms preprocess, 873.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
# -1
